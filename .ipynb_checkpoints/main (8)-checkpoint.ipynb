# %% [markdown]
# # Подключение библиотеки

# %%
import timeit
import time
import sys
import os
import re
import numpy as np
import pandas as pd
import seaborn as sb
from IPython.display import display, HTML
from datetime import datetime

import matplotlib.pyplot as plt

from scipy import stats as st
# Тренды и сезонность
from statsmodels.tsa.seasonal import seasonal_decompose
# Проверка на стационарность
from statsmodels.tsa.stattools import adfuller, kpss
# Проверка на дисперсию с помощью теста Андерсона-Дарлинга
from scipy.stats import anderson

# Разбиение на обучающую, валидационную и тестовую выборку
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, cross_val_predict, TimeSeriesSplit

# Масштабируемость модели
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder

# Многозадачная регрессия
from sklearn.multioutput import MultiOutputRegressor
# Для машинного обучения
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, StackingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from catboost import CatBoostRegressor
# Метод ближайшего соседа KNN
from sklearn.neighbors import KNeighborsRegressor
# Метод опорного вектора, SVR - для регрессии
from sklearn.svm import SVR

# Метрики
from sklearn.metrics import mean_squared_error

from sklearn.pipeline import make_pipeline

# Нейросети
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torch.optim as optim
# Для сборщика мусора
import gc

# %% [markdown]
# # Импорт и анализ данных

# %%
df = pd.read_csv('Amp_C_train.txt')

# %% [markdown]
# ##### Рассмотрим содержимое датасет

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172032 entries, 0 to 172031
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    172032 non-null  float64
#  1   Input   172032 non-null  object
#  2   Output  172032 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 3.9+ MB

# %%
# Приведение к нижнему регистру названия колонки
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#            time input                       output
# 0  0.000000e+00    0j    (1.0785e-42-9.30535e-43j)
# 1  5.000000e-09    0j   (4.00167e-44+4.80805e-45j)
# 2  1.000000e-08    0j   (5.73102e-46+1.23143e-45j)
# 3  1.500000e-08    0j  (-2.47356e-47+3.89672e-47j)
# 4  2.000000e-08    0j  (-1.56497e-48+2.91821e-51j)

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# ## Сделаем датасет в временной ряд

# %%
# Установка колонки 'time' в качестве индекса
df.set_index('time', inplace=True)

# %% [markdown]
# ## Преобразование комплексных входных и выходных сигналов из строкового представления

# %%
df['input'] = df['input'].apply(lambda x: complex(x.strip('()').replace('i', 'j')))
df['output'] = df['output'].apply(lambda x: complex(x.strip('()').replace('i', 'j')))

# %% [markdown]
# ## Изменим DataFrame с реальной и мнимой частями комплексных чисел

# %%
df['input_real'] = df['input'].apply(np.real)
df['input_imag'] = df['input'].apply(np.imag)
df['output_real'] = df['output'].apply(np.real)
df['output_imag'] = df['output'].apply(np.imag)

# %%
df.head()
# Out:
#                  input                                          output  \
# time
# 0.000000e+00  0.0+0.0j  1.078500e-42-9.305350e-                    43j
# 5.000000e-09  0.0+0.0j  4.001670e-44+4.808050e-                    45j
# 1.000000e-08  0.0+0.0j  5.731020e-46+1.231430e-                    45j
# 1.500000e-08  0.0+0.0j -2.473560e-47+3.896720e-                    47j
# 2.000000e-08  0.0+0.0j -1.564970e-48+2.918210e-                    51j
#
#               input_real  input_imag   output_real   output_imag
# time
# 0.000000e+00         0.0         0.0  1.078500e-42 -9.305350e-43
# 5.000000e-09         0.0         0.0  4.001670e-44  4.808050e-45
# 1.000000e-08         0.0         0.0  5.731020e-46  1.231430e-45
# 1.500000e-08         0.0         0.0 -2.473560e-47  3.896720e-47
# 2.000000e-08         0.0         0.0 -1.564970e-48  2.918210e-51

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 172032 entries, 0.0 to 0.000860155
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   input        172032 non-null  complex128
#  1   output       172032 non-null  complex128
#  2   input_real   172032 non-null  float64
#  3   input_imag   172032 non-null  float64
#  4   output_real  172032 non-null  float64
#  5   output_imag  172032 non-null  float64
# dtypes: complex128(2), float64(4)
# memory usage: 11.8 MB

# %%
df = df.drop(['input', 'output'], axis=1)

# %%
df.describe()
# Out:
#           input_real     input_imag    output_real    output_imag
# count  172032.000000  172032.000000  172032.000000  172032.000000
# mean        0.000053      -0.000013      -0.001947      -0.000626
# std         0.592007       0.593872       2.087976       2.087590
# min        -2.229120      -2.202991      -3.449150      -3.441910
# 25%        -0.399091      -0.399775      -1.934853      -1.937512
# 50%        -0.000685      -0.000342      -0.010191       0.004920
# 75%         0.398777       0.401744       1.935345       1.929125
# max         2.212461       2.192265       3.451210       3.460060

# %% [markdown]
# ## График

# %%
def draw_plot_signal(signal_type, time_start=0, time_end=1e-6):
    # Фильтрация данных по временной отметке
    filtered_data = df[(df.index >= time_start) & (df.index <= time_end)]
    time = filtered_data.index

    # Построение объединенного графика
    plt.figure(figsize=(10, 6))
    
    # Входной сигнал
    plt.plot(time, filtered_data[f'{signal_type}_real'], label=f'{signal_type} Real Part', color='blue', linestyle='-')
    plt.plot(time, filtered_data[f'{signal_type}_imag'], label=f'{signal_type} Imaginary Part', color='red', linestyle='-')
    
    plt.title('Input and Output Signals')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def draw_all_plot_signal(time_start=0, time_end=1e-6):
    # Фильтрация данных по временной отметке
    filtered_data = df[(df.index >= time_start) & (df.index <= time_end)]
    time = filtered_data.index
    
    plt.figure(figsize=(15, 10))

    # График реальной части входного сигнала
    plt.subplot(2, 2, 1)
    plt.plot(time, filtered_data['input_real'], label='Real Part')
    plt.title('Real Part of input Signal')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.grid(True)
    
    # График мнимой части входного сигнала
    plt.subplot(2, 2, 2)
    plt.plot(time, filtered_data['input_imag'], label='Imaginary Part', color='orange')
    plt.title('Imaginary Part of input Signal')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.grid(True)
    
    # График реальной части выходного сигнала
    plt.subplot(2, 2, 3)
    plt.plot(time, filtered_data['output_real'], label='Real Part')
    plt.title('Real Part of output Signal')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.grid(True)
    
    # График мнимой части выходного сигнала
    plt.subplot(2, 2, 4)
    plt.plot(time, filtered_data['output_imag'], label='Imaginary Part', color='orange')
    plt.title('Imaginary Part of output Signal')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %%
draw_plot_signal('input', time_start=1e-8, time_end=0.3e-6)

# %%
draw_plot_signal('output', time_start=1e-8, time_end=0.3e-6)

# %%
draw_all_plot_signal(time_start=1e-7, time_end=0.3e-6)

# %% [markdown]
# # Машинное обучение

# %%
# Здесь будем сохранить результаты обучения
results = pd.DataFrame()

# А это будет счетчтиком для нумерация моеделй
count_model = 0

# %%
# Определение входных и выходных данных
features = df[['input_real', 'input_imag']]
targets = df[['output_real', 'output_imag']]

# %% [markdown]
# ## Деление на обучающей и валидационной выборки

# %% [markdown]
# **Обучение моделей с применением TimeSeriesSplit**
#
# Почему обучаем с применением TimeSeriesSplit, потому что мы обучаем модель, у которой по индексу стоит временный ряд. А чтобы они не пересекались, это поможет инструмент TimeSeriesSplit.

# %%
# Не будем создавать по-умолчанию, где n_splits=5, а установим n_splits=10
tscv = TimeSeriesSplit(10)
display(tscv)
# Out:
# TimeSeriesSplit(gap=0, max_train_size=None, n_splits=10, test_size=None)

# %%
# Разделение на обучающую и валидационную выборки
features_train, features_valid, targets_train, targets_valid = train_test_split(features, targets, test_size=0.2, random_state=123456)

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# ### LinearRegression

# %%
# Устанавливаем нужные параметры
parameters = {}

# Инициализируем модель (включая масштабирование) и GridSearchCV
pipeline_scale = make_pipeline(StandardScaler(), LinearRegression())
model = GridSearchCV(pipeline_scale, param_grid=parameters, cv=tscv, scoring='neg_root_mean_squared_error')
display(model)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=10, test_size=None),
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('linearregression',
#                                         LinearRegression())]),
#              param_grid={}, scoring='neg_root_mean_squared_error')

# %%
# Обучим модель на обучающей выборке
model.fit(features_train, targets_train)
time = model.refit_time_
params = model.best_params_

# Узнаем RMSE обучающей выборки
rmse_train = np.sqrt(-model.best_score_)
print('RMSE TRAIN:', rmse_train)
print('TIME TRAIN [s]:', round(time, 2))
# Out:
# RMSE TRAIN: 0.8658672581599522
# TIME TRAIN [s]: 0.02

# %% [markdown]
# **Проверка на валидационной выборки**

# %%
# %%time
start_time = timeit.default_timer()
# Получим предсказания на валидационной выборки
predictions = model.predict(features_valid)

elapsed = round(timeit.default_timer() - start_time, 3)

# Узнаем RMSE output_real и output_imag
rmse_valid_real = np.sqrt(mean_squared_error(targets_valid['output_real'], predictions[:, 0]))
rmse_valid_imag = np.sqrt(mean_squared_error(targets_valid['output_imag'], predictions[:, 1]))

print(f'RMSE для действительной части: {rmse_valid_real}')
print(f'RMSE для мнимой части: {rmse_valid_imag}')
# Out:
# RMSE для действительной части: 0.7488804442530592
# RMSE для мнимой части: 0.7531629903468988
# CPU times: user 13.8 ms, sys: 2.61 ms, total: 16.4 ms
# Wall time: 4.69 ms

# %%
# Зафиксируем результаты
results[count_model] = pd.Series({
    'NAME': pipeline_scale.named_steps[pipeline_scale.steps[-1][0]].__class__.__name__, 
    'RMSE TRAIN': rmse_train, 
    'RMSE VALID REAL': rmse_valid_real, 
    'RMSE VALID IMAG': rmse_valid_imag, 
    'TIME TRAINING [s]': model.refit_time_, 
    'TIME PREDICTION [s]': elapsed, 
    'PREDICTIONS': predictions, 
    'PARAMETRS': model.best_params_
})

display(results[count_model])
count_model+=1
# Out:
# NAME                                                    LinearRegression
# RMSE TRAIN                                                      0.865867
# RMSE VALID REAL                                                  0.74888
# RMSE VALID IMAG                                                 0.753163
# TIME TRAINING [s]                                               0.018766
# TIME PREDICTION [s]                                                0.004
# PREDICTIONS            [[-0.28832698573917814, 1.936889405288186], [-...
# PARAMETRS                                                             {}
# Name: 0, dtype: object

# %% [markdown]
# ### KNeighborsRegressor

# %%
# Задаем значения гиперпараметров
parameters = {
    # Пример значений, можно добавить свои
    'kneighborsregressor__n_neighbors': [1, 2],  
    # 'weights': ['uniform', 'distance'],
    'kneighborsregressor__weights': ['uniform'],
    # для параметра метрики (1 - манхэттенское расстояние, 2 - евклидово расстояние)
    # 'kneighborsregressor__p': [1]  
}

# Инициализируем модель (включая масштабирование) и GridSearchCV
pipeline_scale = make_pipeline(StandardScaler(), KNeighborsRegressor())
model = GridSearchCV(pipeline_scale, param_grid=parameters, cv=tscv, scoring='neg_root_mean_squared_error')
display(model)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=10, test_size=None),
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('kneighborsregressor',
#                                         KNeighborsRegressor())]),
#              param_grid={'kneighborsregressor__n_neighbors': [1, 2],
#                          'kneighborsregressor__weights': ['uniform']},
#              scoring='neg_root_mean_squared_error')

# %%
# Обучим модель на обучающей выборке
model.fit(features_train, targets_train)
time = model.refit_time_
params = model.best_params_

# Узнаем RMSE обучающей выборки
rmse_train = np.sqrt(-model.best_score_)
print('RMSE TRAIN:', rmse_train)
print('TIME TRAIN [s]:', round(time, 2))
# Out:
# RMSE TRAIN: 0.3862943803573481
# TIME TRAIN [s]: 0.06

# %% [markdown]
# **Проверка на валидационной выборки**

# %%
# %%time
start_time = timeit.default_timer()
# Получим предсказания на валидационной выборки
predictions = model.predict(features_valid)

elapsed = round(timeit.default_timer() - start_time, 3)

# Узнаем RMSE output_real и output_imag
rmse_valid_real = np.sqrt(mean_squared_error(targets_valid['output_real'], predictions[:, 0]))
rmse_valid_imag = np.sqrt(mean_squared_error(targets_valid['output_imag'], predictions[:, 1]))

print(f'RMSE для действительной части: {rmse_valid_real}')
print(f'RMSE для мнимой части: {rmse_valid_imag}')
# Out:
# RMSE для действительной части: 0.14756557815883273
# RMSE для мнимой части: 0.1483683860179619
# CPU times: user 102 ms, sys: 2.02 ms, total: 104 ms
# Wall time: 103 ms

# %%
# Зафиксируем результаты
results[count_model] = pd.Series({
    'NAME': pipeline_scale.named_steps[pipeline_scale.steps[-1][0]].__class__.__name__, 
    'RMSE TRAIN': rmse_train, 
    'RMSE VALID REAL': rmse_valid_real, 
    'RMSE VALID IMAG': rmse_valid_imag, 
    'TIME TRAINING [s]': model.refit_time_, 
    'TIME PREDICTION [s]': elapsed, 
    'PREDICTIONS': predictions, 
    'PARAMETRS': model.best_params_
})

display(results[count_model])
count_model+=1
# Out:
# NAME                                                 KNeighborsRegressor
# RMSE TRAIN                                                      0.386294
# RMSE VALID REAL                                                 0.147566
# RMSE VALID IMAG                                                 0.148368
# TIME TRAINING [s]                                               0.061688
# TIME PREDICTION [s]                                                0.102
# PREDICTIONS            [[-0.44020349999999997, 2.974165], [-2.74305, ...
# PARAMETRS              {'kneighborsregressor__n_neighbors': 2, 'kneig...
# Name: 1, dtype: object

# %% [markdown]
# ### DecisionTreeRegressor

# %%
parameters = {
    'decisiontreeregressor__max_depth': range(1, 101, 10),
    'decisiontreeregressor__min_samples_leaf': [1, 0.5]
}

# Инициализируем модель (включая масштабирование) и GridSearchCV
pipeline_scale = make_pipeline(StandardScaler(), DecisionTreeRegressor(random_state=12345))
model = GridSearchCV(pipeline_scale, param_grid=parameters, cv=tscv, scoring='neg_root_mean_squared_error')
display(model)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=10, test_size=None),
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('decisiontreeregressor',
#                                         DecisionTreeRegressor(random_state=12345))]),
#              param_grid={'decisiontreeregressor__max_depth': range(1, 101, 10),
#                          'decisiontreeregressor__min_samples_leaf': [1, 0.5]},
#              scoring='neg_root_mean_squared_error')

# %%
# Обучим модель на обучающей выборке
model.fit(features_train, targets_train)
time = model.refit_time_
params = model.best_params_

# Узнаем RMSE обучающей выборки
rmse_train = np.sqrt(-model.best_score_)
print('RMSE TRAIN:', rmse_train)
print('TIME TRAIN [s]:', round(time, 2))
# Out:
# RMSE TRAIN: 0.37621486671960813
# TIME TRAIN [s]: 0.3

# %% [markdown]
# **Проверка на валидационной выборки**

# %%
# %%time
start_time = timeit.default_timer()
# Получим предсказания на валидационной выборки
predictions = model.predict(features_valid)

elapsed = round(timeit.default_timer() - start_time, 3)

# Узнаем RMSE output_real и output_imag
rmse_valid_real = np.sqrt(mean_squared_error(targets_valid['output_real'], predictions[:, 0]))
rmse_valid_imag = np.sqrt(mean_squared_error(targets_valid['output_imag'], predictions[:, 1]))

print(f'RMSE для действительной части: {rmse_valid_real}')
print(f'RMSE для мнимой части: {rmse_valid_imag}')
# Out:
# RMSE для действительной части: 0.13459805580403986
# RMSE для мнимой части: 0.1339878847137597
# CPU times: user 4.8 ms, sys: 2.98 ms, total: 7.77 ms
# Wall time: 6.32 ms

# %%
# Зафиксируем результаты
results[count_model] = pd.Series({
    'NAME': pipeline_scale.named_steps[pipeline_scale.steps[-1][0]].__class__.__name__, 
    'RMSE TRAIN': rmse_train, 
    'RMSE VALID REAL': rmse_valid_real, 
    'RMSE VALID IMAG': rmse_valid_imag, 
    'TIME TRAINING [s]': model.refit_time_, 
    'TIME PREDICTION [s]': elapsed, 
    'PREDICTIONS': predictions, 
    'PARAMETRS': model.best_params_
})

display(results[count_model])
count_model+=1
# Out:
# NAME                                               DecisionTreeRegressor
# RMSE TRAIN                                                      0.376215
# RMSE VALID REAL                                                 0.134598
# RMSE VALID IMAG                                                 0.133988
# TIME TRAINING [s]                                               0.296888
# TIME PREDICTION [s]                                                0.005
# PREDICTIONS            [[-0.5637410662983423, 2.8974165193370167], [-...
# PARAMETRS              {'decisiontreeregressor__max_depth': 11, 'deci...
# Name: 2, dtype: object

# %% [markdown]
# ### LightGBMRegressor

# %%
# Матрица гиперпараметров для LGBMRegressor
parameters = {
    'multioutputregressor__estimator__n_estimators': [10, 25],
    'multioutputregressor__estimator__learning_rate': [0.1, 0.3],
    'multioutputregressor__estimator__max_depth': [5, 15],
    'multioutputregressor__estimator__num_leaves': [5, 10],
}

# Оборачиваем LGBMR в MultiOutputRegressor
multi_target_lgbmr = MultiOutputRegressor(LGBMRegressor())

# Инициализируем модель с параметрами и создаем конвейер
pipeline_scale = make_pipeline(StandardScaler(), multi_target_lgbmr)
model = GridSearchCV(pipeline_scale, param_grid=parameters, cv=tscv, scoring='neg_root_mean_squared_error')
display(model)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=10, test_size=None),
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('multioutputregressor',
#                                         MultiOutputRegressor(estimator=LGBMRegressor()))]),
#              param_grid={'multioutputregressor__estimator__learning_rate': [0.1,
#                                                                             0.3],
#                          'multioutputregressor__estimator__max_depth': [5, 15],
#                          'multioutputregressor__estimator__n_estimators': [10,
#                                                                            25],
#                          'multioutputregressor__estimator__num_leaves': [5,
#                                                                          10]},
#              scoring='neg_root_mean_squared_error')

# %%
# Обучим модель на обучающей выборке
model.fit(features_train, targets_train)
time = model.refit_time_
params = model.best_params_

# Узнаем RMSE обучающей выборки
rmse_train = np.sqrt(-model.best_score_)
print('RMSE TRAIN:', rmse_train)
print('TIME TRAIN [s]:', round(time, 2))
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000082 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.003815
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000093 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.015188
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000128 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006946
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002189
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score -0.013456
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000082 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000513
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000106 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009501
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004377
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000127 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009639
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000132 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.001302
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006280
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000204
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000186 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006220
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.005439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000259 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004299
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000180 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002615
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000230 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004942
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000214 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.003256
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000233 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004851
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000224 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002023
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000078 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.003815
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000144 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.015188
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000140 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006946
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002189
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score -0.013456
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000100 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000513
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009501
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000238 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004377
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000125 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009639
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000141 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.001302
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006280
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000187 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000204
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000191 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006220
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000192 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.005439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000195 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004299
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000266 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002615
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000252 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004942
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000225 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.003256
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000255 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004851
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000274 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002023
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000098 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.003815
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000095 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.015188
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000066 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000078 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002189
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000088 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score -0.013456
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000087 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000513
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000125 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009501
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004377
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000556 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009639
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000134 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.001302
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006280
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000204
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000171 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006220
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.005439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000196 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004299
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000196 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002615
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000210 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004942
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000219 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.003256
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000236 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004851
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000260 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002023
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000092 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.003815
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000086 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.015188
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000144 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000065 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002189
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000096 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score -0.013456
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000091 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000513
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000120 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009501
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000112 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004377
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000141 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009639
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000127 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.001302
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006280
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000171 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000204
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000205 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006220
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000191 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.005439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000213 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004299
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000201 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002615
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000208 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004942
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000174 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.003256
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000160 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004851
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000212 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002023
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.003815
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.015188
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000068 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000064 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002189
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000090 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score -0.013456
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000089 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000513
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000116 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009501
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000112 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004377
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000160 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009639
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.001302
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000191 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006280
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000183 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000204
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000181 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006220
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000211 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.005439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000193 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004299
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000192 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002615
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000221 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004942
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000239 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.003256
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000272 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004851
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000256 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002023
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000129 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.003815
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000082 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.015188
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000158 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000076 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002189
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000091 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score -0.013456
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000513
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000139 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009501
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000129 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004377
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000392 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009639
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.001302
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006280
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000167 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000204
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000186 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006220
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000238 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.005439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000202 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004299
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000203 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002615
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000257 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004942
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000247 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.003256
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000259 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004851
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000254 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002023
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000095 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.003815
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000180 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# ...
# [LightGBM] [Info] Start training from score 0.015188
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000074 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006946
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000157 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002189
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000111 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score -0.013456
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000407 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000513
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009501
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004377
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009639
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000164 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.001302
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000175 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006280
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000201 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000204
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000187 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006220
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000202 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.005439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000208 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004299
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000235 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002615
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000254 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004942
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001311 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.003256
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000338 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004851
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000307 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002023
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.003815
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000491 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 12515, number of used features: 2
# [LightGBM] [Info] Start training from score 0.015188
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000079 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006946
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 25026, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002189
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000101 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score -0.013456
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000099 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 37537, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000513
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000135 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009501
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000130 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 50048, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004377
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.009639
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 62559, number of used features: 2
# [LightGBM] [Info] Start training from score -0.001302
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000166 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006280
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000170 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 75070, number of used features: 2
# [LightGBM] [Info] Start training from score 0.000204
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000197 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.006220
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000190 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 87581, number of used features: 2
# [LightGBM] [Info] Start training from score -0.005439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000226 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004299
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000215 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 100092, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002615
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000244 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004942
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000258 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 112603, number of used features: 2
# [LightGBM] [Info] Start training from score -0.003256
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000282 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.004851
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000262 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 125114, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002023
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000293 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 137625, number of used features: 2
# [LightGBM] [Info] Start training from score -0.005104
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000297 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 137625, number of used features: 2
# [LightGBM] [Info] Start training from score -0.002344
# RMSE TRAIN: 0.41636163622260586
# TIME TRAIN [s]: 0.13

# %% [markdown]
# **Проверка на валидационной выборки**

# %%
# %%time
start_time = timeit.default_timer()
# Получим предсказания на валидационной выборки
predictions = model.predict(features_valid)

elapsed = round(timeit.default_timer() - start_time, 3)

# Узнаем RMSE output_real и output_imag
rmse_valid_real = np.sqrt(mean_squared_error(targets_valid['output_real'], predictions[:, 0]))
rmse_valid_imag = np.sqrt(mean_squared_error(targets_valid['output_imag'], predictions[:, 1]))

print(f'RMSE для действительной части: {rmse_valid_real}')
print(f'RMSE для мнимой части: {rmse_valid_imag}')
# Out:
# RMSE для действительной части: 0.1713299102926755
# RMSE для мнимой части: 0.1723867719656781
# CPU times: user 132 ms, sys: 9.17 ms, total: 141 ms
# Wall time: 17.6 ms

# %%
# Зафиксируем результаты
results[count_model] = pd.Series({
    'NAME': pipeline_scale.named_steps[pipeline_scale.steps[-1][0]].__class__.__name__, 
    'RMSE TRAIN': rmse_train, 
    'RMSE VALID REAL': rmse_valid_real, 
    'RMSE VALID IMAG': rmse_valid_imag, 
    'TIME TRAINING [s]': model.refit_time_, 
    'TIME PREDICTION [s]': elapsed, 
    'PREDICTIONS': predictions, 
    'PARAMETRS': model.best_params_
})

display(results[count_model])
count_model+=1
# Out:
# NAME                                                MultiOutputRegressor
# RMSE TRAIN                                                      0.416362
# RMSE VALID REAL                                                  0.17133
# RMSE VALID IMAG                                                 0.172387
# TIME TRAINING [s]                                               0.126176
# TIME PREDICTION [s]                                                0.016
# PREDICTIONS            [[-0.33606733176649484, 3.0045329003957586], [...
# PARAMETRS              {'multioutputregressor__estimator__learning_ra...
# Name: 3, dtype: object

# %% [markdown]
# ### CatBoostRegressor

# %%
# Матрица гиперпараметров для CatBoostRegressor
parameters = {
    'multioutputregressor__estimator__iterations': [5, 10],
    'multioutputregressor__estimator__learning_rate': [0.1, 0.5],
    'multioutputregressor__estimator__depth': [5, 15],
}

# Оборачиваем CatBoostRegressor в MultiOutputRegressor
multi_target_cbr = MultiOutputRegressor(CatBoostRegressor())

# Инициализируем модель с параметрами и создаем конвейер
pipeline_scale = make_pipeline(StandardScaler(), multi_target_cbr)
model = GridSearchCV(pipeline_scale, param_grid=parameters, cv=tscv, scoring='neg_root_mean_squared_error')
display(model)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=10, test_size=None),
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('multioutputregressor',
#                                         MultiOutputRegressor(estimator=<catboost.core.CatBoostRegressor object at 0x78989bd3fc10>))]),
#              param_grid={'multioutputregressor__estimator__depth': [5, 15],
#                          'multioutputregressor__estimator__iterations': [5, 10],
#                          'multioutputregressor__estimator__learning_rate': [0.1,
#                                                                             0.5]},
#              scoring='neg_root_mean_squared_error')

# %%
# Обучим модель на обучающей выборке
model.fit(features_train, targets_train)
time = model.refit_time_
params = model.best_params_

# Узнаем RMSE обучающей выборки
rmse_train = np.sqrt(-model.best_score_)
print('RMSE TRAIN:', rmse_train)
print('TIME TRAIN [s]:', round(time, 2))
# Out:
# 0:	learn: 1.9013737	total: 48.4ms	remaining: 193ms
# 1:	learn: 1.7306095	total: 50.2ms	remaining: 75.3ms
# 2:	learn: 1.5795488	total: 52.6ms	remaining: 35.1ms
# 3:	learn: 1.4394106	total: 54.5ms	remaining: 13.6ms
# 4:	learn: 1.3128407	total: 56.2ms	remaining: 0us
# 0:	learn: 1.9010003	total: 5.93ms	remaining: 23.7ms
# 1:	learn: 1.7313272	total: 8.95ms	remaining: 13.4ms
# 2:	learn: 1.5814113	total: 11.8ms	remaining: 7.85ms
# 3:	learn: 1.4447014	total: 15.1ms	remaining: 3.78ms
# 4:	learn: 1.3188330	total: 18.6ms	remaining: 0us
# 0:	learn: 1.9039942	total: 2.17ms	remaining: 8.69ms
# 1:	learn: 1.7343293	total: 4ms	remaining: 6ms
# 2:	learn: 1.5823872	total: 5.87ms	remaining: 3.91ms
# 3:	learn: 1.4419239	total: 7.95ms	remaining: 1.99ms
# 4:	learn: 1.3152449	total: 10ms	remaining: 0us
# 0:	learn: 1.9005997	total: 1.68ms	remaining: 6.72ms
# 1:	learn: 1.7316318	total: 3.11ms	remaining: 4.67ms
# 2:	learn: 1.5763051	total: 4.64ms	remaining: 3.09ms
# 3:	learn: 1.4377097	total: 6.38ms	remaining: 1.59ms
# 4:	learn: 1.3136369	total: 8.53ms	remaining: 0us
# 0:	learn: 1.8959267	total: 3.08ms	remaining: 12.3ms
# 1:	learn: 1.7272990	total: 6.52ms	remaining: 9.78ms
# 2:	learn: 1.5734611	total: 8.98ms	remaining: 5.99ms
# 3:	learn: 1.4347039	total: 12ms	remaining: 2.99ms
# 4:	learn: 1.3082796	total: 15.1ms	remaining: 0us
# 0:	learn: 1.9052224	total: 3.84ms	remaining: 15.4ms
# 1:	learn: 1.7344448	total: 7.17ms	remaining: 10.8ms
# 2:	learn: 1.5796806	total: 9.96ms	remaining: 6.64ms
# 3:	learn: 1.4414407	total: 13.3ms	remaining: 3.33ms
# 4:	learn: 1.3165721	total: 15.6ms	remaining: 0us
# 0:	learn: 1.8969970	total: 2.71ms	remaining: 10.9ms
# 1:	learn: 1.7272857	total: 5.07ms	remaining: 7.6ms
# 2:	learn: 1.5738318	total: 7.69ms	remaining: 5.13ms
# 3:	learn: 1.4350427	total: 11ms	remaining: 2.74ms
# 4:	learn: 1.3090994	total: 13.3ms	remaining: 0us
# 0:	learn: 1.9009440	total: 3.46ms	remaining: 13.8ms
# 1:	learn: 1.7309545	total: 7.97ms	remaining: 12ms
# 2:	learn: 1.5762120	total: 12.2ms	remaining: 8.15ms
# 3:	learn: 1.4384124	total: 15.7ms	remaining: 3.91ms
# 4:	learn: 1.3136953	total: 19.1ms	remaining: 0us
# 0:	learn: 1.8987287	total: 4.07ms	remaining: 16.3ms
# 1:	learn: 1.7282185	total: 7.67ms	remaining: 11.5ms
# 2:	learn: 1.5736291	total: 11.4ms	remaining: 7.58ms
# 3:	learn: 1.4344926	total: 14.6ms	remaining: 3.65ms
# 4:	learn: 1.3095051	total: 18ms	remaining: 0us
# 0:	learn: 1.9005237	total: 3.67ms	remaining: 14.7ms
# 1:	learn: 1.7328836	total: 8.13ms	remaining: 12.2ms
# 2:	learn: 1.5783384	total: 11.2ms	remaining: 7.44ms
# 3:	learn: 1.4400474	total: 15.1ms	remaining: 3.79ms
# 4:	learn: 1.3141332	total: 18.7ms	remaining: 0us
# 0:	learn: 1.8990360	total: 3.76ms	remaining: 15ms
# 1:	learn: 1.7286094	total: 6.77ms	remaining: 10.2ms
# 2:	learn: 1.5742029	total: 10.5ms	remaining: 6.99ms
# 3:	learn: 1.4352106	total: 13.5ms	remaining: 3.36ms
# 4:	learn: 1.3104732	total: 16.8ms	remaining: 0us
# 0:	learn: 1.8998280	total: 3.42ms	remaining: 13.7ms
# 1:	learn: 1.7310210	total: 6.71ms	remaining: 10.1ms
# 2:	learn: 1.5773290	total: 10.2ms	remaining: 6.8ms
# 3:	learn: 1.4398191	total: 12.9ms	remaining: 3.22ms
# 4:	learn: 1.3147244	total: 16.1ms	remaining: 0us
# 0:	learn: 1.9000039	total: 4.08ms	remaining: 16.3ms
# 1:	learn: 1.7291287	total: 8.21ms	remaining: 12.3ms
# 2:	learn: 1.5743641	total: 12.3ms	remaining: 8.17ms
# 3:	learn: 1.4356072	total: 16ms	remaining: 4.01ms
# 4:	learn: 1.3104513	total: 21.3ms	remaining: 0us
# 0:	learn: 1.8999054	total: 4.46ms	remaining: 17.9ms
# 1:	learn: 1.7312069	total: 8.92ms	remaining: 13.4ms
# 2:	learn: 1.5757715	total: 12.9ms	remaining: 8.61ms
# 3:	learn: 1.4375502	total: 16.9ms	remaining: 4.21ms
# 4:	learn: 1.3122262	total: 21.1ms	remaining: 0us
# 0:	learn: 1.8997774	total: 4.38ms	remaining: 17.5ms
# 1:	learn: 1.7299299	total: 10.1ms	remaining: 15.1ms
# 2:	learn: 1.5758979	total: 14.6ms	remaining: 9.7ms
# 3:	learn: 1.4360587	total: 19.2ms	remaining: 4.8ms
# 4:	learn: 1.3122492	total: 25.2ms	remaining: 0us
# 0:	learn: 1.8981025	total: 5.28ms	remaining: 21.1ms
# 1:	learn: 1.7280699	total: 10.4ms	remaining: 15.6ms
# 2:	learn: 1.5739784	total: 15.3ms	remaining: 10.2ms
# 3:	learn: 1.4363234	total: 20.4ms	remaining: 5.1ms
# 4:	learn: 1.3111351	total: 24.9ms	remaining: 0us
# 0:	learn: 1.8988878	total: 6.33ms	remaining: 25.3ms
# 1:	learn: 1.7297113	total: 13ms	remaining: 19.6ms
# 2:	learn: 1.5760341	total: 18.8ms	remaining: 12.5ms
# 3:	learn: 1.4364822	total: 24ms	remaining: 6ms
# 4:	learn: 1.3109967	total: 28.8ms	remaining: 0us
# 0:	learn: 1.8980436	total: 5.98ms	remaining: 23.9ms
# 1:	learn: 1.7277509	total: 10.4ms	remaining: 15.6ms
# 2:	learn: 1.5740471	total: 14.1ms	remaining: 9.39ms
# 3:	learn: 1.4360176	total: 21.3ms	remaining: 5.32ms
# 4:	learn: 1.3110658	total: 26.3ms	remaining: 0us
# 0:	learn: 1.8985125	total: 6.57ms	remaining: 26.3ms
# 1:	learn: 1.7293654	total: 11.8ms	remaining: 17.7ms
# 2:	learn: 1.5756519	total: 18.2ms	remaining: 12.1ms
# 3:	learn: 1.4361855	total: 24.4ms	remaining: 6.09ms
# 4:	learn: 1.3108040	total: 29.4ms	remaining: 0us
# 0:	learn: 1.8987095	total: 6.31ms	remaining: 25.2ms
# 1:	learn: 1.7283075	total: 12.1ms	remaining: 18.2ms
# 2:	learn: 1.5740084	total: 17.9ms	remaining: 12ms
# 3:	learn: 1.4361457	total: 23.8ms	remaining: 5.95ms
# 4:	learn: 1.3113345	total: 30.2ms	remaining: 0us
# 0:	learn: 1.1841657	total: 1.59ms	remaining: 6.38ms
# 1:	learn: 0.7051032	total: 3.08ms	remaining: 4.63ms
# 2:	learn: 0.4747590	total: 4.67ms	remaining: 3.11ms
# 3:	learn: 0.3681514	total: 6.12ms	remaining: 1.53ms
# 4:	learn: 0.3090105	total: 7.71ms	remaining: 0us
# 0:	learn: 1.1874406	total: 1.34ms	remaining: 5.36ms
# 1:	learn: 0.7187016	total: 2.88ms	remaining: 4.31ms
# 2:	learn: 0.5034880	total: 4.16ms	remaining: 2.77ms
# 3:	learn: 0.3749257	total: 5.66ms	remaining: 1.41ms
# 4:	learn: 0.3193985	total: 7.21ms	remaining: 0us
# 0:	learn: 1.1854241	total: 1.67ms	remaining: 6.68ms
# 1:	learn: 0.7061825	total: 4.13ms	remaining: 6.19ms
# 2:	learn: 0.4778620	total: 6.33ms	remaining: 4.22ms
# 3:	learn: 0.3603626	total: 8.75ms	remaining: 2.19ms
# 4:	learn: 0.3005982	total: 11.7ms	remaining: 0us
# 0:	learn: 1.1827708	total: 1.81ms	remaining: 7.25ms
# 1:	learn: 0.7151846	total: 3.82ms	remaining: 5.73ms
# 2:	learn: 0.4922505	total: 5.53ms	remaining: 3.69ms
# 3:	learn: 0.3691075	total: 7.38ms	remaining: 1.85ms
# 4:	learn: 0.3127691	total: 9.79ms	remaining: 0us
# 0:	learn: 1.1809939	total: 2.27ms	remaining: 9.1ms
# 1:	learn: 0.7048656	total: 6.08ms	remaining: 9.12ms
# 2:	learn: 0.4767267	total: 8.76ms	remaining: 5.84ms
# 3:	learn: 0.3654368	total: 11.1ms	remaining: 2.78ms
# 4:	learn: 0.3052023	total: 14.3ms	remaining: 0us
# 0:	learn: 1.1837281	total: 2.1ms	remaining: 8.42ms
# 1:	learn: 0.7109829	total: 4.3ms	remaining: 6.45ms
# 2:	learn: 0.4910339	total: 6.38ms	remaining: 4.25ms
# 3:	learn: 0.3646265	total: 8.3ms	remaining: 2.07ms
# 4:	learn: 0.3086536	total: 10.2ms	remaining: 0us
# 0:	learn: 1.1772154	total: 2.64ms	remaining: 10.6ms
# 1:	learn: 0.7169193	total: 4.95ms	remaining: 7.42ms
# 2:	learn: 0.4752519	total: 7.83ms	remaining: 5.22ms
# 3:	learn: 0.3601421	total: 10.6ms	remaining: 2.65ms
# 4:	learn: 0.3024653	total: 13.1ms	remaining: 0us
# 0:	learn: 1.1810387	total: 2.44ms	remaining: 9.76ms
# 1:	learn: 0.7110108	total: 4.82ms	remaining: 7.23ms
# 2:	learn: 0.4916753	total: 7.18ms	remaining: 4.79ms
# 3:	learn: 0.3680957	total: 9.66ms	remaining: 2.42ms
# 4:	learn: 0.3092112	total: 13.2ms	remaining: 0us
# 0:	learn: 1.1808886	total: 3.51ms	remaining: 14.1ms
# 1:	learn: 0.7025604	total: 5.99ms	remaining: 8.98ms
# 2:	learn: 0.4680481	total: 8.77ms	remaining: 5.84ms
# 3:	learn: 0.3556158	total: 11.9ms	remaining: 2.98ms
# 4:	learn: 0.3062019	total: 14.6ms	remaining: 0us
# 0:	learn: 1.1765848	total: 2.54ms	remaining: 10.2ms
# 1:	learn: 0.7116585	total: 5.58ms	remaining: 8.38ms
# 2:	learn: 0.4802002	total: 7.79ms	remaining: 5.19ms
# 3:	learn: 0.3623975	total: 10.1ms	remaining: 2.53ms
# 4:	learn: 0.3134304	total: 12.8ms	remaining: 0us
# 0:	learn: 1.1771829	total: 2.97ms	remaining: 11.9ms
# 1:	learn: 0.7097924	total: 5.77ms	remaining: 8.66ms
# 2:	learn: 0.4703300	total: 8.34ms	remaining: 5.56ms
# 3:	learn: 0.3615497	total: 11.1ms	remaining: 2.77ms
# 4:	learn: 0.3047550	total: 14.2ms	remaining: 0us
# 0:	learn: 1.1761582	total: 4.73ms	remaining: 18.9ms
# 1:	learn: 0.7066260	total: 7.91ms	remaining: 11.9ms
# 2:	learn: 0.4784993	total: 11.6ms	remaining: 7.75ms
# 3:	learn: 0.3636784	total: 14.7ms	remaining: 3.68ms
# 4:	learn: 0.3107800	total: 18.1ms	remaining: 0us
# 0:	learn: 1.1830696	total: 4.06ms	remaining: 16.3ms
# 1:	learn: 0.7042168	total: 7.63ms	remaining: 11.4ms
# 2:	learn: 0.4744194	total: 11.6ms	remaining: 7.72ms
# 3:	learn: 0.3618491	total: 15.1ms	remaining: 3.78ms
# 4:	learn: 0.3070609	total: 18.3ms	remaining: 0us
# 0:	learn: 1.1822209	total: 5.11ms	remaining: 20.4ms
# 1:	learn: 0.7117068	total: 9.24ms	remaining: 13.9ms
# 2:	learn: 0.4894895	total: 13.4ms	remaining: 8.9ms
# 3:	learn: 0.3581304	total: 17.2ms	remaining: 4.3ms
# 4:	learn: 0.3051049	total: 20.7ms	remaining: 0us
# 0:	learn: 1.1772742	total: 4.92ms	remaining: 19.7ms
# 1:	learn: 0.7214126	total: 9.41ms	remaining: 14.1ms
# 2:	learn: 0.4831479	total: 14.2ms	remaining: 9.48ms
# 3:	learn: 0.3627262	total: 20.6ms	remaining: 5.16ms
# 4:	learn: 0.3061710	total: 25.8ms	remaining: 0us
# 0:	learn: 1.1798175	total: 7.27ms	remaining: 29.1ms
# 1:	learn: 0.7178769	total: 12.4ms	remaining: 18.6ms
# 2:	learn: 0.4815783	total: 19.7ms	remaining: 13.1ms
# 3:	learn: 0.3731549	total: 25.1ms	remaining: 6.26ms
# 4:	learn: 0.3169907	total: 31.2ms	remaining: 0us
# 0:	learn: 1.1769171	total: 7.02ms	remaining: 28.1ms
# 1:	learn: 0.7218025	total: 13.6ms	remaining: 20.4ms
# 2:	learn: 0.4735925	total: 21.9ms	remaining: 14.6ms
# 3:	learn: 0.3562089	total: 28.9ms	remaining: 7.22ms
# 4:	learn: 0.3013283	total: 33.6ms	remaining: 0us
# 0:	learn: 1.1787120	total: 4.71ms	remaining: 18.8ms
# 1:	learn: 0.7137701	total: 9.98ms	remaining: 15ms
# 2:	learn: 0.4882887	total: 14.5ms	remaining: 9.65ms
# 3:	learn: 0.3716334	total: 18.9ms	remaining: 4.71ms
# 4:	learn: 0.3217494	total: 22.6ms	remaining: 0us
# 0:	learn: 1.1767811	total: 6.46ms	remaining: 25.8ms
# 1:	learn: 0.7210815	total: 12.5ms	remaining: 18.7ms
# 2:	learn: 0.4726143	total: 18ms	remaining: 12ms
# 3:	learn: 0.3572203	total: 22.5ms	remaining: 5.63ms
# 4:	learn: 0.2992018	total: 26.7ms	remaining: 0us
# 0:	learn: 1.1788652	total: 16.9ms	remaining: 67.7ms
# 1:	learn: 0.7134843	total: 26.9ms	remaining: 40.3ms
# 2:	learn: 0.4877414	total: 38.4ms	remaining: 25.6ms
# 3:	learn: 0.3715989	total: 47.6ms	remaining: 11.9ms
# 4:	learn: 0.3213975	total: 54.6ms	remaining: 0us
# 0:	learn: 1.9013737	total: 2.37ms	remaining: 21.3ms
# 1:	learn: 1.7306095	total: 4.69ms	remaining: 18.8ms
# 2:	learn: 1.5795488	total: 6.08ms	remaining: 14.2ms
# 3:	learn: 1.4394106	total: 7.47ms	remaining: 11.2ms
# 4:	learn: 1.3128407	total: 9.03ms	remaining: 9.03ms
# 5:	learn: 1.2008472	total: 10.3ms	remaining: 6.89ms
# 6:	learn: 1.0992736	total: 11.8ms	remaining: 5.06ms
# 7:	learn: 1.0084178	total: 13.2ms	remaining: 3.29ms
# 8:	learn: 0.9270673	total: 14.4ms	remaining: 1.6ms
# 9:	learn: 0.8529886	total: 15.9ms	remaining: 0us
# 0:	learn: 1.9010003	total: 1.76ms	remaining: 15.8ms
# 1:	learn: 1.7313272	total: 4.16ms	remaining: 16.6ms
# 2:	learn: 1.5814113	total: 5.95ms	remaining: 13.9ms
# 3:	learn: 1.4447014	total: 7.73ms	remaining: 11.6ms
# 4:	learn: 1.3188330	total: 9.86ms	remaining: 9.86ms
# 5:	learn: 1.2042323	total: 11.6ms	remaining: 7.72ms
# 6:	learn: 1.1026146	total: 12.9ms	remaining: 5.54ms
# 7:	learn: 1.0130464	total: 14.8ms	remaining: 3.7ms
# 8:	learn: 0.9305902	total: 16.4ms	remaining: 1.82ms
# 9:	learn: 0.8554343	total: 17.7ms	remaining: 0us
# 0:	learn: 1.9039942	total: 3.26ms	remaining: 29.3ms
# 1:	learn: 1.7343293	total: 5.06ms	remaining: 20.3ms
# 2:	learn: 1.5823872	total: 7.19ms	remaining: 16.8ms
# 3:	learn: 1.4419239	total: 9.27ms	remaining: 13.9ms
# 4:	learn: 1.3152449	total: 11.5ms	remaining: 11.5ms
# 5:	learn: 1.2065684	total: 13.4ms	remaining: 8.96ms
# 6:	learn: 1.1033052	total: 15.7ms	remaining: 6.72ms
# 7:	learn: 1.0118157	total: 17.8ms	remaining: 4.46ms
# 8:	learn: 0.9289596	total: 19.6ms	remaining: 2.18ms
# 9:	learn: 0.8531812	total: 21.9ms	remaining: 0us
# 0:	learn: 1.9005997	total: 1.62ms	remaining: 14.6ms
# 1:	learn: 1.7316318	total: 3.43ms	remaining: 13.7ms
# 2:	learn: 1.5763051	total: 5.67ms	remaining: 13.2ms
# 3:	learn: 1.4377097	total: 7.25ms	remaining: 10.9ms
# 4:	learn: 1.3136369	total: 8.79ms	remaining: 8.79ms
# 5:	learn: 1.1998736	total: 10.4ms	remaining: 6.94ms
# 6:	learn: 1.0991866	total: 12.2ms	remaining: 5.21ms
# 7:	learn: 1.0088454	total: 14ms	remaining: 3.49ms
# 8:	learn: 0.9259551	total: 15.7ms	remaining: 1.74ms
# 9:	learn: 0.8511120	total: 17.4ms	remaining: 0us
# 0:	learn: 1.8959267	total: 2.59ms	remaining: 23.3ms
# 1:	learn: 1.7272990	total: 4.98ms	remaining: 19.9ms
# 2:	learn: 1.5734611	total: 7.57ms	remaining: 17.7ms
# 3:	learn: 1.4347039	total: 11.5ms	remaining: 17.2ms
# 4:	learn: 1.3082796	total: 15ms	remaining: 15ms
# 5:	learn: 1.1975032	total: 17.3ms	remaining: 11.5ms
# 6:	learn: 1.0969687	total: 20.4ms	remaining: 8.76ms
# 7:	learn: 1.0060021	total: 23.5ms	remaining: 5.87ms
# 8:	learn: 0.9227821	total: 25.7ms	remaining: 2.85ms
# 9:	learn: 0.8482510	total: 28.6ms	remaining: 0us
# 0:	learn: 1.9052224	total: 2.78ms	remaining: 25.1ms
# 1:	learn: 1.7344448	total: 5.33ms	remaining: 21.3ms
# 2:	learn: 1.5796806	total: 7.22ms	remaining: 16.8ms
# 3:	learn: 1.4414407	total: 9.29ms	remaining: 13.9ms
# 4:	learn: 1.3165721	total: 11.4ms	remaining: 11.4ms
# 5:	learn: 1.2022701	total: 13.5ms	remaining: 9.01ms
# 6:	learn: 1.1011912	total: 16.6ms	remaining: 7.11ms
# 7:	learn: 1.0112535	total: 18.7ms	remaining: 4.67ms
# 8:	learn: 0.9269219	total: 20.7ms	remaining: 2.3ms
# 9:	learn: 0.8518113	total: 25.2ms	remaining: 0us
# 0:	learn: 1.8969970	total: 2.68ms	remaining: 24.2ms
# 1:	learn: 1.7272857	total: 5.57ms	remaining: 22.3ms
# 2:	learn: 1.5738318	total: 9.81ms	remaining: 22.9ms
# 3:	learn: 1.4350427	total: 12.9ms	remaining: 19.4ms
# 4:	learn: 1.3090994	total: 15.5ms	remaining: 15.5ms
# 5:	learn: 1.1976249	total: 18.5ms	remaining: 12.3ms
# 6:	learn: 1.0949583	total: 20.8ms	remaining: 8.91ms
# 7:	learn: 1.0048926	total: 23ms	remaining: 5.75ms
# 8:	learn: 0.9223585	total: 25.7ms	remaining: 2.85ms
# 9:	learn: 0.8480565	total: 27.6ms	remaining: 0us
# 0:	learn: 1.9009440	total: 2.47ms	remaining: 22.3ms
# 1:	learn: 1.7309545	total: 4.54ms	remaining: 18.2ms
# 2:	learn: 1.5762120	total: 6.56ms	remaining: 15.3ms
# 3:	learn: 1.4384124	total: 9.2ms	remaining: 13.8ms
# 4:	learn: 1.3136953	total: 11.4ms	remaining: 11.4ms
# 5:	learn: 1.1999722	total: 14.5ms	remaining: 9.68ms
# 6:	learn: 1.0986243	total: 17.1ms	remaining: 7.32ms
# 7:	learn: 1.0085944	total: 19.2ms	remaining: 4.81ms
# 8:	learn: 0.9249469	total: 21.6ms	remaining: 2.4ms
# 9:	learn: 0.8495230	total: 24.2ms	remaining: 0us
# 0:	learn: 1.8987287	total: 3.27ms	remaining: 29.4ms
# 1:	learn: 1.7282185	total: 6.16ms	remaining: 24.6ms
# 2:	learn: 1.5736291	total: 8.76ms	remaining: 20.4ms
# 3:	learn: 1.4344926	total: 11.4ms	remaining: 17.1ms
# 4:	learn: 1.3095051	total: 14.6ms	remaining: 14.6ms
# 5:	learn: 1.1980141	total: 18.5ms	remaining: 12.3ms
# 6:	learn: 1.0972311	total: 22.2ms	remaining: 9.53ms
# 7:	learn: 1.0068927	total: 24.8ms	remaining: 6.19ms
# 8:	learn: 0.9221066	total: 27.2ms	remaining: 3.03ms
# 9:	learn: 0.8476958	total: 30.2ms	remaining: 0us
# 0:	learn: 1.9005237	total: 2.83ms	remaining: 25.4ms
# 1:	learn: 1.7328836	total: 5.39ms	remaining: 21.6ms
# 2:	learn: 1.5783384	total: 7.78ms	remaining: 18.1ms
# 3:	learn: 1.4400474	total: 10.5ms	remaining: 15.7ms
# 4:	learn: 1.3141332	total: 13ms	remaining: 13ms
# 5:	learn: 1.2007614	total: 15.5ms	remaining: 10.3ms
# 6:	learn: 1.1000408	total: 18.3ms	remaining: 7.84ms
# 7:	learn: 1.0065523	total: 21.3ms	remaining: 5.33ms
# 8:	learn: 0.9235285	total: 25.4ms	remaining: 2.82ms
# 9:	learn: 0.8480553	total: 28ms	remaining: 0us
# 0:	learn: 1.8990360	total: 3.36ms	remaining: 30.2ms
# 1:	learn: 1.7286094	total: 7.38ms	remaining: 29.5ms
# 2:	learn: 1.5742029	total: 10.4ms	remaining: 24.4ms
# 3:	learn: 1.4352106	total: 14.3ms	remaining: 21.5ms
# 4:	learn: 1.3104732	total: 18.5ms	remaining: 18.5ms
# 5:	learn: 1.1984282	total: 22.5ms	remaining: 15ms
# 6:	learn: 1.0969973	total: 25.8ms	remaining: 11.1ms
# 7:	learn: 1.0069011	total: 29.6ms	remaining: 7.4ms
# 8:	learn: 0.9225825	total: 33.4ms	remaining: 3.71ms
# 9:	learn: 0.8483368	total: 36.4ms	remaining: 0us
# 0:	learn: 1.8998280	total: 3.01ms	remaining: 27.1ms
# 1:	learn: 1.7310210	total: 6.32ms	remaining: 25.3ms
# 2:	learn: 1.5773290	total: 9.38ms	remaining: 21.9ms
# 3:	learn: 1.4398191	total: 12.3ms	remaining: 18.5ms
# 4:	learn: 1.3147244	total: 15.6ms	remaining: 15.6ms
# 5:	learn: 1.1998512	total: 18.7ms	remaining: 12.5ms
# 6:	learn: 1.0986155	total: 22.5ms	remaining: 9.64ms
# 7:	learn: 1.0080867	total: 25.3ms	remaining: 6.33ms
# 8:	learn: 0.9250166	total: 28.7ms	remaining: 3.19ms
# 9:	learn: 0.8505307	total: 31.6ms	remaining: 0us
# 0:	learn: 1.9000039	total: 2.65ms	remaining: 23.8ms
# 1:	learn: 1.7291287	total: 6.2ms	remaining: 24.8ms
# 2:	learn: 1.5743641	total: 9.62ms	remaining: 22.5ms
# 3:	learn: 1.4356072	total: 12.9ms	remaining: 19.3ms
# 4:	learn: 1.3104513	total: 16.5ms	remaining: 16.5ms
# 5:	learn: 1.1992368	total: 21ms	remaining: 14ms
# 6:	learn: 1.0980818	total: 24.5ms	remaining: 10.5ms
# 7:	learn: 1.0080256	total: 28.8ms	remaining: 7.19ms
# 8:	learn: 0.9235964	total: 32.4ms	remaining: 3.6ms
# 9:	learn: 0.8481741	total: 36.2ms	remaining: 0us
# 0:	learn: 1.8999054	total: 6.7ms	remaining: 60.3ms
# 1:	learn: 1.7312069	total: 11.8ms	remaining: 47.1ms
# 2:	learn: 1.5757715	total: 16.8ms	remaining: 39.3ms
# 3:	learn: 1.4375502	total: 23.1ms	remaining: 34.6ms
# 4:	learn: 1.3122262	total: 28.8ms	remaining: 28.8ms
# 5:	learn: 1.2011451	total: 33.5ms	remaining: 22.4ms
# 6:	learn: 1.0984272	total: 39.3ms	remaining: 16.9ms
# 7:	learn: 1.0082710	total: 44.8ms	remaining: 11.2ms
# 8:	learn: 0.9250156	total: 50.4ms	remaining: 5.6ms
# 9:	learn: 0.8490088	total: 55.4ms	remaining: 0us
# 0:	learn: 1.8997774	total: 4.09ms	remaining: 36.8ms
# 1:	learn: 1.7299299	total: 8.09ms	remaining: 32.4ms
# 2:	learn: 1.5758979	total: 12.8ms	remaining: 29.9ms
# 3:	learn: 1.4360587	total: 19.6ms	remaining: 29.4ms
# 4:	learn: 1.3122492	total: 26.7ms	remaining: 26.7ms
# 5:	learn: 1.1995267	total: 32.4ms	remaining: 21.6ms
# 6:	learn: 1.0983636	total: 38.5ms	remaining: 16.5ms
# 7:	learn: 1.0059774	total: 45.4ms	remaining: 11.4ms
# 8:	learn: 0.9236562	total: 51.1ms	remaining: 5.68ms
# 9:	learn: 0.8496944	total: 56ms	remaining: 0us
# 0:	learn: 1.8981025	total: 5.55ms	remaining: 50ms
# 1:	learn: 1.7280699	total: 10ms	remaining: 40.2ms
# 2:	learn: 1.5739784	total: 13.9ms	remaining: 32.4ms
# 3:	learn: 1.4363234	total: 18.4ms	remaining: 27.5ms
# 4:	learn: 1.3111351	total: 22.2ms	remaining: 22.2ms
# 5:	learn: 1.1997491	total: 27.5ms	remaining: 18.3ms
# 6:	learn: 1.0967646	total: 32ms	remaining: 13.7ms
# 7:	learn: 1.0048249	total: 38.6ms	remaining: 9.65ms
# 8:	learn: 0.9226971	total: 42.8ms	remaining: 4.75ms
# 9:	learn: 0.8489301	total: 46.9ms	remaining: 0us
# 0:	learn: 1.8988878	total: 4.57ms	remaining: 41.1ms
# 1:	learn: 1.7297113	total: 9.21ms	remaining: 36.8ms
# 2:	learn: 1.5760341	total: 13.5ms	remaining: 31.6ms
# 3:	learn: 1.4364822	total: 17.6ms	remaining: 26.4ms
# 4:	learn: 1.3109967	total: 22.7ms	remaining: 22.7ms
# 5:	learn: 1.2003060	total: 27.6ms	remaining: 18.4ms
# 6:	learn: 1.0992417	total: 32.7ms	remaining: 14ms
# 7:	learn: 1.0078002	total: 37.3ms	remaining: 9.33ms
# 8:	learn: 0.9251355	total: 43.3ms	remaining: 4.82ms
# 9:	learn: 0.8505873	total: 47.4ms	remaining: 0us
# 0:	learn: 1.8980436	total: 5.36ms	remaining: 48.2ms
# 1:	learn: 1.7277509	total: 12.4ms	remaining: 49.6ms
# 2:	learn: 1.5740471	total: 19.8ms	remaining: 46.2ms
# 3:	learn: 1.4360176	total: 27.6ms	remaining: 41.4ms
# 4:	learn: 1.3110658	total: 32.5ms	remaining: 32.5ms
# 5:	learn: 1.2001300	total: 37.3ms	remaining: 24.9ms
# 6:	learn: 1.0986028	total: 43.3ms	remaining: 18.6ms
# 7:	learn: 1.0070673	total: 48.5ms	remaining: 12.1ms
# 8:	learn: 0.9250262	total: 56ms	remaining: 6.22ms
# 9:	learn: 0.8493977	total: 61.4ms	remaining: 0us
# 0:	learn: 1.8985125	total: 6.25ms	remaining: 56.3ms
# 1:	learn: 1.7293654	total: 14.8ms	remaining: 59.3ms
# 2:	learn: 1.5756519	total: 22.8ms	remaining: 53.3ms
# 3:	learn: 1.4361855	total: 29.2ms	remaining: 43.8ms
# 4:	learn: 1.3108040	total: 36.9ms	remaining: 36.9ms
# 5:	learn: 1.2001413	total: 43.1ms	remaining: 28.7ms
# 6:	learn: 1.0988074	total: 49.1ms	remaining: 21ms
# 7:	learn: 1.0069037	total: 57.7ms	remaining: 14.4ms
# 8:	learn: 0.9246305	total: 64.1ms	remaining: 7.12ms
# 9:	learn: 0.8512182	total: 70.1ms	remaining: 0us
# 0:	learn: 1.8987095	total: 6.9ms	remaining: 62.1ms
# 1:	learn: 1.7283075	total: 13.3ms	remaining: 53ms
# 2:	learn: 1.5740084	total: 17.9ms	remaining: 41.9ms
# 3:	learn: 1.4361457	total: 23.1ms	remaining: 34.6ms
# 4:	learn: 1.3113345	total: 29.1ms	remaining: 29.1ms
# 5:	learn: 1.2005886	total: 33.7ms	remaining: 22.4ms
# 6:	learn: 1.0997098	total: 38.5ms	remaining: 16.5ms
# 7:	learn: 1.0078555	total: 45ms	remaining: 11.3ms
# 8:	learn: 0.9255498	total: 49.7ms	remaining: 5.52ms
# 9:	learn: 0.8507114	total: 54ms	remaining: 0us
# 0:	learn: 1.1841657	total: 1.38ms	remaining: 12.4ms
# 1:	learn: 0.7051032	total: 3.13ms	remaining: 12.5ms
# 2:	learn: 0.4747590	total: 4.83ms	remaining: 11.3ms
# 3:	learn: 0.3681514	total: 6.39ms	remaining: 9.59ms
# 4:	learn: 0.3090105	total: 8.01ms	remaining: 8.01ms
# 5:	learn: 0.2862752	total: 9.6ms	remaining: 6.4ms
# 6:	learn: 0.2675364	total: 11ms	remaining: 4.7ms
# 7:	learn: 0.2587926	total: 12.3ms	remaining: 3.07ms
# 8:	learn: 0.2520517	total: 13.7ms	remaining: 1.53ms
# 9:	learn: 0.2392184	total: 15.2ms	remaining: 0us
# 0:	learn: 1.1874406	total: 1.42ms	remaining: 12.8ms
# 1:	learn: 0.7187016	total: 2.96ms	remaining: 11.8ms
# 2:	learn: 0.5034880	total: 4.42ms	remaining: 10.3ms
# 3:	learn: 0.3749257	total: 6.08ms	remaining: 9.12ms
# 4:	learn: 0.3193985	total: 7.42ms	remaining: 7.42ms
# 5:	learn: 0.2930206	total: 8.99ms	remaining: 5.99ms
# 6:	learn: 0.2782455	total: 10.6ms	remaining: 4.54ms
# 7:	learn: 0.2654927	total: 12.1ms	remaining: 3.02ms
# 8:	learn: 0.2591263	total: 13.3ms	remaining: 1.48ms
# 9:	learn: 0.2430188	total: 14.6ms	remaining: 0us
# 0:	learn: 1.1854241	total: 1.82ms	remaining: 16.4ms
# 1:	learn: 0.7061825	total: 3.47ms	remaining: 13.9ms
# 2:	learn: 0.4778620	total: 5.02ms	remaining: 11.7ms
# 3:	learn: 0.3603626	total: 6.9ms	remaining: 10.3ms
# 4:	learn: 0.3005982	total: 8.82ms	remaining: 8.82ms
# 5:	learn: 0.2749879	total: 10.3ms	remaining: 6.86ms
# 6:	learn: 0.2640752	total: 12.1ms	remaining: 5.2ms
# 7:	learn: 0.2508043	total: 13.7ms	remaining: 3.43ms
# 8:	learn: 0.2368258	total: 15.2ms	remaining: 1.69ms
# 9:	learn: 0.2287463	total: 16.7ms	remaining: 0us
# 0:	learn: 1.1827708	total: 1.42ms	remaining: 12.8ms
# 1:	learn: 0.7151846	total: 2.92ms	remaining: 11.7ms
# 2:	learn: 0.4922505	total: 4.67ms	remaining: 10.9ms
# 3:	learn: 0.3691075	total: 6.33ms	remaining: 9.5ms
# 4:	learn: 0.3127691	total: 7.75ms	remaining: 7.75ms
# 5:	learn: 0.2861578	total: 9.32ms	remaining: 6.22ms
# 6:	learn: 0.2630807	total: 11.5ms	remaining: 4.94ms
# 7:	learn: 0.2509811	total: 13.6ms	remaining: 3.41ms
# 8:	learn: 0.2416574	total: 15.3ms	remaining: 1.7ms
# 9:	learn: 0.2320200	total: 17ms	remaining: 0us
# 0:	learn: 1.1809939	total: 1.79ms	remaining: 16.1ms
# 1:	learn: 0.7048656	total: 3.82ms	remaining: 15.3ms
# 2:	learn: 0.4767267	total: 5.99ms	remaining: 14ms
# 3:	learn: 0.3654368	total: 9.78ms	remaining: 14.7ms
# 4:	learn: 0.3052023	total: 12.4ms	remaining: 12.4ms
# 5:	learn: 0.2749719	total: 14.2ms	remaining: 9.48ms
# 6:	learn: 0.2621859	total: 16.4ms	remaining: 7.04ms
# 7:	learn: 0.2484961	total: 19ms	remaining: 4.76ms
# 8:	learn: 0.2347233	total: 21.1ms	remaining: 2.34ms
# 9:	learn: 0.2259102	total: 23.8ms	remaining: 0us
# 0:	learn: 1.1837281	total: 3.3ms	remaining: 29.7ms
# 1:	learn: 0.7109829	total: 5.6ms	remaining: 22.4ms
# 2:	learn: 0.4910339	total: 7.79ms	remaining: 18.2ms
# 3:	learn: 0.3646265	total: 10.2ms	remaining: 15.3ms
# 4:	learn: 0.3086536	total: 12.4ms	remaining: 12.4ms
# 5:	learn: 0.2843187	total: 14.9ms	remaining: 9.96ms
# 6:	learn: 0.2655522	total: 17.1ms	remaining: 7.35ms
# 7:	learn: 0.2560930	total: 19.2ms	remaining: 4.8ms
# 8:	learn: 0.2406124	total: 22.2ms	remaining: 2.47ms
# 9:	learn: 0.2322868	total: 24.4ms	remaining: 0us
# 0:	learn: 1.1772154	total: 3.15ms	remaining: 28.4ms
# 1:	learn: 0.7169193	total: 6.44ms	remaining: 25.8ms
# 2:	learn: 0.4752519	total: 9.41ms	remaining: 22ms
# 3:	learn: 0.3601421	total: 11.8ms	remaining: 17.8ms
# 4:	learn: 0.3024653	total: 14.4ms	remaining: 14.4ms
# 5:	learn: 0.2768407	total: 16.4ms	remaining: 10.9ms
# 6:	learn: 0.2615632	total: 18.6ms	remaining: 7.96ms
# 7:	learn: 0.2501368	total: 21ms	remaining: 5.24ms
# 8:	learn: 0.2389699	total: 23.2ms	remaining: 2.58ms
# 9:	learn: 0.2297499	total: 25.4ms	remaining: 0us
# 0:	learn: 1.1810387	total: 3.46ms	remaining: 31.2ms
# 1:	learn: 0.7110108	total: 7.53ms	remaining: 30.1ms
# 2:	learn: 0.4916753	total: 10.4ms	remaining: 24.3ms
# 3:	learn: 0.3680957	total: 14.4ms	remaining: 21.6ms
# 4:	learn: 0.3092112	total: 16.8ms	remaining: 16.8ms
# 5:	learn: 0.2839733	total: 21.1ms	remaining: 14.1ms
# 6:	learn: 0.2707187	total: 23.4ms	remaining: 10ms
# 7:	learn: 0.2562389	total: 25.8ms	remaining: 6.45ms
# 8:	learn: 0.2446222	total: 28.3ms	remaining: 3.15ms
# 9:	learn: 0.2396808	total: 31.3ms	remaining: 0us
# 0:	learn: 1.1808886	total: 2.5ms	remaining: 22.5ms
# 1:	learn: 0.7025604	total: 4.98ms	remaining: 19.9ms
# 2:	learn: 0.4680481	total: 7.98ms	remaining: 18.6ms
# 3:	learn: 0.3556158	total: 10.4ms	remaining: 15.6ms
# 4:	learn: 0.3062019	total: 12.7ms	remaining: 12.7ms
# 5:	learn: 0.2808365	total: 15.7ms	remaining: 10.4ms
# 6:	learn: 0.2623633	total: 18.5ms	remaining: 7.94ms
# 7:	learn: 0.2484932	total: 22.2ms	remaining: 5.55ms
# 8:	learn: 0.2418253	total: 25.2ms	remaining: 2.79ms
# 9:	learn: 0.2297402	total: 27.7ms	remaining: 0us
# 0:	learn: 1.1765848	total: 2.83ms	remaining: 25.5ms
# 1:	learn: 0.7116585	total: 6.22ms	remaining: 24.9ms
# 2:	learn: 0.4802002	total: 8.73ms	remaining: 20.4ms
# 3:	learn: 0.3623975	total: 11.4ms	remaining: 17.1ms
# 4:	learn: 0.3134304	total: 13.9ms	remaining: 13.9ms
# 5:	learn: 0.2833941	total: 16.2ms	remaining: 10.8ms
# 6:	learn: 0.2672845	total: 19.2ms	remaining: 8.22ms
# 7:	learn: 0.2552032	total: 21.7ms	remaining: 5.42ms
# 8:	learn: 0.2467196	total: 24.3ms	remaining: 2.7ms
# 9:	learn: 0.2393974	total: 27.2ms	remaining: 0us
# 0:	learn: 1.1771829	total: 3.05ms	remaining: 27.5ms
# 1:	learn: 0.7097924	total: 8.64ms	remaining: 34.6ms
# 2:	learn: 0.4703300	total: 11.8ms	remaining: 27.6ms
# 3:	learn: 0.3615497	total: 14.8ms	remaining: 22.2ms
# 4:	learn: 0.3047550	total: 18.8ms	remaining: 18.8ms
# 5:	learn: 0.2794379	total: 21.5ms	remaining: 14.3ms
# 6:	learn: 0.2650018	total: 24.9ms	remaining: 10.7ms
# 7:	learn: 0.2524079	total: 27.9ms	remaining: 6.98ms
# 8:	learn: 0.2414700	total: 31.3ms	remaining: 3.47ms
# 9:	learn: 0.2323229	total: 34ms	remaining: 0us
# 0:	learn: 1.1761582	total: 5.73ms	remaining: 51.6ms
# 1:	learn: 0.7066260	total: 12.9ms	remaining: 51.5ms
# 2:	learn: 0.4784993	total: 17.1ms	remaining: 39.9ms
# 3:	learn: 0.3636784	total: 29.3ms	remaining: 43.9ms
# 4:	learn: 0.3107800	total: 36.5ms	remaining: 36.5ms
# 5:	learn: 0.2849996	total: 42.7ms	remaining: 28.5ms
# 6:	learn: 0.2649329	total: 53.6ms	remaining: 23ms
# 7:	learn: 0.2533668	total: 59ms	remaining: 14.8ms
# 8:	learn: 0.2445938	total: 64.8ms	remaining: 7.19ms
# 9:	learn: 0.2349803	total: 71ms	remaining: 0us
# 0:	learn: 1.1830696	total: 4.24ms	remaining: 38.2ms
# 1:	learn: 0.7042168	total: 7.82ms	remaining: 31.3ms
# 2:	learn: 0.4744194	total: 11.5ms	remaining: 26.8ms
# 3:	learn: 0.3618491	total: 15.2ms	remaining: 22.8ms
# 4:	learn: 0.3070609	total: 20.1ms	remaining: 20.1ms
# 5:	learn: 0.2811555	total: 24.5ms	remaining: 16.4ms
# 6:	learn: 0.2713400	total: 28.2ms	remaining: 12.1ms
# 7:	learn: 0.2570108	total: 34.3ms	remaining: 8.59ms
# 8:	learn: 0.2431863	total: 39.2ms	remaining: 4.35ms
# 9:	learn: 0.2334179	total: 43.6ms	remaining: 0us
# 0:	learn: 1.1822209	total: 4.38ms	remaining: 39.5ms
# 1:	learn: 0.7117068	total: 8.57ms	remaining: 34.3ms
# 2:	learn: 0.4894895	total: 13.7ms	remaining: 32ms
# 3:	learn: 0.3581304	total: 16.8ms	remaining: 25.2ms
# 4:	learn: 0.3051049	total: 20.3ms	remaining: 20.3ms
# 5:	learn: 0.2771844	total: 23.3ms	remaining: 15.6ms
# 6:	learn: 0.2572620	total: 27ms	remaining: 11.6ms
# 7:	learn: 0.2441988	total: 30.2ms	remaining: 7.56ms
# 8:	learn: 0.2338692	total: 35ms	remaining: 3.89ms
# 9:	learn: 0.2285975	total: 39.2ms	remaining: 0us
# 0:	learn: 1.1772742	total: 6.78ms	remaining: 61.1ms
# 1:	learn: 0.7214126	total: 12.1ms	remaining: 48.4ms
# 2:	learn: 0.4831479	total: 17.3ms	remaining: 40.4ms
# 3:	learn: 0.3627262	total: 24ms	remaining: 36ms
# 4:	learn: 0.3061710	total: 27.8ms	remaining: 27.8ms
# 5:	learn: 0.2770886	total: 32.3ms	remaining: 21.5ms
# 6:	learn: 0.2606234	total: 36ms	remaining: 15.4ms
# 7:	learn: 0.2464738	total: 40.9ms	remaining: 10.2ms
# 8:	learn: 0.2350340	total: 46.7ms	remaining: 5.19ms
# 9:	learn: 0.2260738	total: 52ms	remaining: 0us
# 0:	learn: 1.1798175	total: 6.57ms	remaining: 59.2ms
# 1:	learn: 0.7178769	total: 11.2ms	remaining: 45ms
# 2:	learn: 0.4815783	total: 15.4ms	remaining: 35.8ms
# 3:	learn: 0.3731549	total: 20ms	remaining: 30ms
# 4:	learn: 0.3169907	total: 24.1ms	remaining: 24.1ms
# 5:	learn: 0.2913436	total: 28.4ms	remaining: 18.9ms
# 6:	learn: 0.2682105	total: 32.6ms	remaining: 14ms
# 7:	learn: 0.2551156	total: 37.9ms	remaining: 9.47ms
# 8:	learn: 0.2441190	total: 41.8ms	remaining: 4.64ms
# 9:	learn: 0.2326327	total: 45.1ms	remaining: 0us
# 0:	learn: 1.1769171	total: 4.83ms	remaining: 43.5ms
# 1:	learn: 0.7218025	total: 9.41ms	remaining: 37.7ms
# 2:	learn: 0.4735925	total: 15.2ms	remaining: 35.6ms
# 3:	learn: 0.3562089	total: 20.3ms	remaining: 30.4ms
# 4:	learn: 0.3013283	total: 24.2ms	remaining: 24.2ms
# 5:	learn: 0.2743672	total: 28.9ms	remaining: 19.3ms
# 6:	learn: 0.2593760	total: 33.9ms	remaining: 14.5ms
# 7:	learn: 0.2509764	total: 38.9ms	remaining: 9.73ms
# 8:	learn: 0.2405675	total: 43.1ms	remaining: 4.79ms
# 9:	learn: 0.2286214	total: 48.6ms	remaining: 0us
# 0:	learn: 1.1787120	total: 4.73ms	remaining: 42.6ms
# 1:	learn: 0.7137701	total: 11.6ms	remaining: 46.4ms
# 2:	learn: 0.4882887	total: 18.2ms	remaining: 42.5ms
# 3:	learn: 0.3716334	total: 24ms	remaining: 36.1ms
# 4:	learn: 0.3217494	total: 29.1ms	remaining: 29.1ms
# 5:	learn: 0.2917656	total: 35.9ms	remaining: 23.9ms
# 6:	learn: 0.2733337	total: 43.3ms	remaining: 18.6ms
# 7:	learn: 0.2562902	total: 51.2ms	remaining: 12.8ms
# 8:	learn: 0.2431548	total: 59.6ms	remaining: 6.62ms
# 9:	learn: 0.2342779	total: 64.1ms	remaining: 0us
# 0:	learn: 1.1767811	total: 7.79ms	remaining: 70.1ms
# 1:	learn: 0.7210815	total: 16.3ms	remaining: 65.4ms
# 2:	learn: 0.4726143	total: 26.5ms	remaining: 61.9ms
# 3:	learn: 0.3572203	total: 35.6ms	remaining: 53.3ms
# 4:	learn: 0.2992018	total: 43.8ms	remaining: 43.8ms
# 5:	learn: 0.2754793	total: 49.7ms	remaining: 33.1ms
# 6:	learn: 0.2583753	total: 56ms	remaining: 24ms
# 7:	learn: 0.2446755	total: 61ms	remaining: 15.2ms
# 8:	learn: 0.2338039	total: 67.2ms	remaining: 7.46ms
# 9:	learn: 0.2249300	total: 73.2ms	remaining: 0us
# 0:	learn: 1.1788652	total: 4.94ms	remaining: 44.5ms
# 1:	learn: 0.7134843	total: 9.61ms	remaining: 38.4ms
# 2:	learn: 0.4877414	total: 13.7ms	remaining: 31.9ms
# 3:	learn: 0.3715989	total: 18.7ms	remaining: 28.1ms
# 4:	learn: 0.3213975	total: 23.2ms	remaining: 23.2ms
# 5:	learn: 0.2915254	total: 27.6ms	remaining: 18.4ms
# 6:	learn: 0.2682978	total: 33.3ms	remaining: 14.3ms
# 7:	learn: 0.2550768	total: 39.4ms	remaining: 9.85ms
# 8:	learn: 0.2420507	total: 44.3ms	remaining: 4.92ms
# 9:	learn: 0.2334107	total: 49.7ms	remaining: 0us
# 0:	learn: 1.8901006	total: 304ms	remaining: 1.22s
# 1:	learn: 1.7102935	total: 592ms	remaining: 888ms
# 2:	learn: 1.5494119	total: 969ms	remaining: 646ms
# 3:	learn: 1.4030253	total: 1.25s	remaining: 312ms
# 4:	learn: 1.2722798	total: 1.5s	remaining: 0us
# 0:	learn: 1.8887840	total: 312ms	remaining: 1.25s
# 1:	learn: 1.7095533	total: 599ms	remaining: 898ms
# 2:	learn: 1.5469852	total: 878ms	remaining: 585ms
# 3:	learn: 1.3998355	total: 1.13s	remaining: 282ms
# 4:	learn: 1.2682901	total: 1.29s	remaining: 0us
# 0:	learn: 1.8903201	total: 239ms	remaining: 956ms
# 1:	learn: 1.7088090	total: 499ms	remaining: 749ms
# 2:	learn: 1.5466868	total: 765ms	remaining: 510ms
# 3:	learn: 1.3996862	total: 1.02s	remaining: 256ms
# 4:	learn: 1.2683478	total: 1.16s	remaining: 0us
# 0:	learn: 1.8878760	total: 272ms	remaining: 1.09s
# 1:	learn: 1.7073183	total: 546ms	remaining: 819ms
# 2:	learn: 1.5453990	total: 797ms	remaining: 531ms
# 3:	learn: 1.3981714	total: 1.05s	remaining: 263ms
# 4:	learn: 1.2658032	total: 1.32s	remaining: 0us
# 0:	learn: 1.8818396	total: 247ms	remaining: 987ms
# 1:	learn: 1.7009671	total: 509ms	remaining: 764ms
# 2:	learn: 1.5383396	total: 774ms	remaining: 516ms
# 3:	learn: 1.3919057	total: 1.02s	remaining: 255ms
# 4:	learn: 1.2598150	total: 1.29s	remaining: 0us
# 0:	learn: 1.8925583	total: 282ms	remaining: 1.13s
# 1:	learn: 1.7106318	total: 553ms	remaining: 830ms
# 2:	learn: 1.5461154	total: 807ms	remaining: 538ms
# 3:	learn: 1.3985317	total: 1.1s	remaining: 274ms
# 4:	learn: 1.2641173	total: 1.35s	remaining: 0us
# 0:	learn: 1.8835892	total: 242ms	remaining: 967ms
# 1:	learn: 1.7024456	total: 504ms	remaining: 756ms
# 2:	learn: 1.5391240	total: 791ms	remaining: 527ms
# 3:	learn: 1.3921227	total: 1.05s	remaining: 264ms
# 4:	learn: 1.2583227	total: 1.34s	remaining: 0us
# 0:	learn: 1.8879928	total: 278ms	remaining: 1.11s
# 1:	learn: 1.7063929	total: 532ms	remaining: 798ms
# 2:	learn: 1.5426060	total: 796ms	remaining: 530ms
# 3:	learn: 1.3953703	total: 1.07s	remaining: 269ms
# 4:	learn: 1.2615147	total: 1.34s	remaining: 0us
# 0:	learn: 1.8848223	total: 266ms	remaining: 1.06s
# 1:	learn: 1.7030088	total: 516ms	remaining: 774ms
# 2:	learn: 1.5395416	total: 800ms	remaining: 534ms
# 3:	learn: 1.3923777	total: 1.05s	remaining: 263ms
# 4:	learn: 1.2587636	total: 1.29s	remaining: 0us
# 0:	learn: 1.8874625	total: 247ms	remaining: 987ms
# 1:	learn: 1.7056416	total: 522ms	remaining: 782ms
# 2:	learn: 1.5410200	total: 795ms	remaining: 530ms
# 3:	learn: 1.3939955	total: 1.06s	remaining: 264ms
# 4:	learn: 1.2603989	total: 1.3s	remaining: 0us
# 0:	learn: 1.8851563	total: 258ms	remaining: 1.03s
# 1:	learn: 1.7032754	total: 509ms	remaining: 764ms
# 2:	learn: 1.5392677	total: 787ms	remaining: 525ms
# 3:	learn: 1.3923168	total: 1.04s	remaining: 259ms
# 4:	learn: 1.2590231	total: 1.29s	remaining: 0us
# 0:	learn: 1.8866676	total: 245ms	remaining: 980ms
# 1:	learn: 1.7049397	total: 528ms	remaining: 792ms
# 2:	learn: 1.5410238	total: 772ms	remaining: 515ms
# 3:	learn: 1.3932643	total: 1.04s	remaining: 260ms
# 4:	learn: 1.2590163	total: 1.31s	remaining: 0us
# 0:	learn: 1.8854481	total: 311ms	remaining: 1.25s
# 1:	learn: 1.7025697	total: 583ms	remaining: 875ms
# 2:	learn: 1.5373766	total: 831ms	remaining: 554ms
# 3:	learn: 1.3899107	total: 1.08s	remaining: 269ms
# 4:	learn: 1.2563637	total: 1.34s	remaining: 0us
# 0:	learn: 1.8863542	total: 255ms	remaining: 1.02s
# 1:	learn: 1.7045959	total: 526ms	remaining: 789ms
# 2:	learn: 1.5392662	total: 808ms	remaining: 538ms
# 3:	learn: 1.3908403	total: 1.09s	remaining: 273ms
# 4:	learn: 1.2571188	total: 1.35s	remaining: 0us
# 0:	learn: 1.8870861	total: 248ms	remaining: 992ms
# 1:	learn: 1.7053841	total: 518ms	remaining: 776ms
# 2:	learn: 1.5417684	total: 777ms	remaining: 518ms
# 3:	learn: 1.3939402	total: 1.05s	remaining: 264ms
# 4:	learn: 1.2604365	total: 1.32s	remaining: 0us
# 0:	learn: 1.8845526	total: 281ms	remaining: 1.12s
# 1:	learn: 1.7018814	total: 571ms	remaining: 856ms
# 2:	learn: 1.5370280	total: 814ms	remaining: 542ms
# 3:	learn: 1.3891210	total: 1.06s	remaining: 266ms
# 4:	learn: 1.2549704	total: 1.32s	remaining: 0us
# 0:	learn: 1.8861385	total: 280ms	remaining: 1.12s
# 1:	learn: 1.7044698	total: 545ms	remaining: 818ms
# 2:	learn: 1.5399112	total: 801ms	remaining: 534ms
# 3:	learn: 1.3925693	total: 1.07s	remaining: 267ms
# 4:	learn: 1.2587724	total: 1.34s	remaining: 0us
# 0:	learn: 1.8842569	total: 240ms	remaining: 960ms
# 1:	learn: 1.7017768	total: 517ms	remaining: 776ms
# 2:	learn: 1.5369523	total: 779ms	remaining: 519ms
# 3:	learn: 1.3886982	total: 1.04s	remaining: 260ms
# 4:	learn: 1.2547288	total: 1.32s	remaining: 0us
# 0:	learn: 1.8857150	total: 281ms	remaining: 1.12s
# 1:	learn: 1.7041459	total: 530ms	remaining: 795ms
# 2:	learn: 1.5395777	total: 802ms	remaining: 535ms
# 3:	learn: 1.3922863	total: 1.08s	remaining: 269ms
# 4:	learn: 1.2584762	total: 1.34s	remaining: 0us
# 0:	learn: 1.8848916	total: 249ms	remaining: 996ms
# 1:	learn: 1.7027910	total: 522ms	remaining: 782ms
# 2:	learn: 1.5376061	total: 816ms	remaining: 544ms
# 3:	learn: 1.3897221	total: 1.06s	remaining: 266ms
# 4:	learn: 1.2556774	total: 1.36s	remaining: 0us
# 0:	learn: 1.1062256	total: 233ms	remaining: 931ms
# 1:	learn: 0.6135677	total: 481ms	remaining: 721ms
# 2:	learn: 0.3654264	total: 723ms	remaining: 482ms
# 3:	learn: 0.2489386	total: 991ms	remaining: 248ms
# 4:	learn: 0.2004218	total: 1.23s	remaining: 0us
# 0:	learn: 1.1025787	total: 262ms	remaining: 1.05s
# 1:	learn: 0.6079175	total: 530ms	remaining: 795ms
# 2:	learn: 0.3577085	total: 775ms	remaining: 516ms
# 3:	learn: 0.2458702	total: 1.02s	remaining: 254ms
# 4:	learn: 0.1995504	total: 1.07s	remaining: 0us
# 0:	learn: 1.0929447	total: 279ms	remaining: 1.12s
# 1:	learn: 0.5932492	total: 536ms	remaining: 804ms
# 2:	learn: 0.3459795	total: 818ms	remaining: 545ms
# 3:	learn: 0.2366253	total: 1.11s	remaining: 278ms
# 4:	learn: 0.1953493	total: 1.25s	remaining: 0us
# 0:	learn: 1.0966794	total: 283ms	remaining: 1.13s
# 1:	learn: 0.6012552	total: 542ms	remaining: 813ms
# 2:	learn: 0.3516485	total: 789ms	remaining: 526ms
# 3:	learn: 0.2456427	total: 1.03s	remaining: 257ms
# 4:	learn: 0.1973822	total: 1.3s	remaining: 0us
# 0:	learn: 1.0865983	total: 270ms	remaining: 1.08s
# 1:	learn: 0.5882519	total: 521ms	remaining: 781ms
# 2:	learn: 0.3420764	total: 765ms	remaining: 510ms
# 3:	learn: 0.2328289	total: 1.01s	remaining: 252ms
# 4:	learn: 0.1906051	total: 1.14s	remaining: 0us
# 0:	learn: 1.0987050	total: 252ms	remaining: 1.01s
# 1:	learn: 0.5951110	total: 513ms	remaining: 769ms
# 2:	learn: 0.3498981	total: 804ms	remaining: 536ms
# 3:	learn: 0.2412748	total: 1.1s	remaining: 276ms
# 4:	learn: 0.1986056	total: 1.35s	remaining: 0us
# 0:	learn: 1.0874049	total: 299ms	remaining: 1.2s
# 1:	learn: 0.5849338	total: 568ms	remaining: 852ms
# 2:	learn: 0.3404562	total: 836ms	remaining: 557ms
# 3:	learn: 0.2336591	total: 1.1s	remaining: 275ms
# 4:	learn: 0.1922020	total: 1.24s	remaining: 0us
# 0:	learn: 1.0945270	total: 245ms	remaining: 979ms
# 1:	learn: 0.5867606	total: 513ms	remaining: 769ms
# 2:	learn: 0.3411605	total: 794ms	remaining: 529ms
# 3:	learn: 0.2353102	total: 1.06s	remaining: 265ms
# 4:	learn: 0.1928962	total: 1.31s	remaining: 0us
# 0:	learn: 1.0882590	total: 287ms	remaining: 1.15s
# 1:	learn: 0.5802684	total: 552ms	remaining: 828ms
# 2:	learn: 0.3399829	total: 562ms	remaining: 375ms
# 3:	learn: 0.2290119	total: 836ms	remaining: 209ms
# 4:	learn: 0.1835890	total: 1.1s	remaining: 0us
# 0:	learn: 1.0893537	total: 257ms	remaining: 1.03s
# 1:	learn: 0.5832866	total: 500ms	remaining: 750ms
# 2:	learn: 0.3388998	total: 758ms	remaining: 505ms
# 3:	learn: 0.2301678	total: 1.05s	remaining: 262ms
# 4:	learn: 0.1865630	total: 1.31s	remaining: 0us
# 0:	learn: 1.0845323	total: 270ms	remaining: 1.08s
# 1:	learn: 0.5791096	total: 585ms	remaining: 877ms
# 2:	learn: 0.3339929	total: 838ms	remaining: 559ms
# 3:	learn: 0.2278795	total: 1.09s	remaining: 272ms
# 4:	learn: 0.1846329	total: 1.34s	remaining: 0us
# 0:	learn: 1.0883984	total: 266ms	remaining: 1.06s
# 1:	learn: 0.5860781	total: 510ms	remaining: 765ms
# 2:	learn: 0.3405863	total: 806ms	remaining: 537ms
# 3:	learn: 0.2335008	total: 1.07s	remaining: 268ms
# 4:	learn: 0.1904683	total: 1.32s	remaining: 0us
# 0:	learn: 1.0865126	total: 307ms	remaining: 1.23s
# 1:	learn: 0.5820474	total: 582ms	remaining: 873ms
# 2:	learn: 0.3362023	total: 875ms	remaining: 583ms
# 3:	learn: 0.2294153	total: 1.14s	remaining: 285ms
# 4:	learn: 0.1885557	total: 1.41s	remaining: 0us
# 0:	learn: 1.0923786	total: 277ms	remaining: 1.11s
# 1:	learn: 0.5851161	total: 565ms	remaining: 848ms
# 2:	learn: 0.3384783	total: 819ms	remaining: 546ms
# 3:	learn: 0.2321859	total: 1.12s	remaining: 280ms
# 4:	learn: 0.1904321	total: 1.25s	remaining: 0us
# 0:	learn: 1.0930748	total: 262ms	remaining: 1.05s
# 1:	learn: 0.5849373	total: 528ms	remaining: 792ms
# 2:	learn: 0.3391566	total: 796ms	remaining: 530ms
# 3:	learn: 0.2307867	total: 1.05s	remaining: 263ms
# 4:	learn: 0.1883478	total: 1.32s	remaining: 0us
# 0:	learn: 1.0899534	total: 242ms	remaining: 969ms
# 1:	learn: 0.5858255	total: 509ms	remaining: 763ms
# 2:	learn: 0.3422114	total: 806ms	remaining: 537ms
# 3:	learn: 0.2318719	total: 1.07s	remaining: 267ms
# 4:	learn: 0.1871154	total: 1.34s	remaining: 0us
# 0:	learn: 1.0924086	total: 255ms	remaining: 1.02s
# 1:	learn: 0.5843571	total: 536ms	remaining: 804ms
# 2:	learn: 0.3371765	total: 805ms	remaining: 536ms
# 3:	learn: 0.2272827	total: 1.09s	remaining: 272ms
# 4:	learn: 0.1824807	total: 1.38s	remaining: 0us
# 0:	learn: 1.0872577	total: 277ms	remaining: 1.11s
# 1:	learn: 0.5862745	total: 547ms	remaining: 821ms
# 2:	learn: 0.3377893	total: 826ms	remaining: 551ms
# 3:	learn: 0.2268259	total: 1.08s	remaining: 271ms
# 4:	learn: 0.1821925	total: 1.38s	remaining: 0us
# 0:	learn: 1.0920094	total: 296ms	remaining: 1.19s
# 1:	learn: 0.5813719	total: 575ms	remaining: 863ms
# 2:	learn: 0.3360744	total: 828ms	remaining: 552ms
# 3:	learn: 0.2282433	total: 1.12s	remaining: 280ms
# 4:	learn: 0.1868600	total: 1.38s	remaining: 0us
# 0:	learn: 1.0872402	total: 258ms	remaining: 1.03s
# 1:	learn: 0.5815949	total: 525ms	remaining: 787ms
# 2:	learn: 0.3360159	total: 812ms	remaining: 541ms
# 3:	learn: 0.2278164	total: 1.11s	remaining: 278ms
# 4:	learn: 0.1827976	total: 1.36s	remaining: 0us
# 0:	learn: 1.8901006	total: 284ms	remaining: 2.56s
# 1:	learn: 1.7102935	total: 545ms	remaining: 2.18s
# 2:	learn: 1.5494119	total: 809ms	remaining: 1.89s
# 3:	learn: 1.4030253	total: 1.07s	remaining: 1.61s
# 4:	learn: 1.2722798	total: 1.34s	remaining: 1.34s
# 5:	learn: 1.1538690	total: 1.61s	remaining: 1.08s
# 6:	learn: 1.0481287	total: 1.63s	remaining: 697ms
# 7:	learn: 0.9500220	total: 1.88s	remaining: 470ms
# 8:	learn: 0.8616097	total: 2.14s	remaining: 238ms
# 9:	learn: 0.7819487	total: 2.41s	remaining: 0us
# 0:	learn: 1.8887840	total: 303ms	remaining: 2.73s
# 1:	learn: 1.7095533	total: 566ms	remaining: 2.26s
# 2:	learn: 1.5469852	total: 831ms	remaining: 1.94s
# 3:	learn: 1.3998355	total: 1.1s	remaining: 1.65s
# 4:	learn: 1.2682901	total: 1.23s	remaining: 1.23s
# 5:	learn: 1.1491958	total: 1.51s	remaining: 1.01s
# 6:	learn: 1.0420470	total: 1.53s	remaining: 657ms
# 7:	learn: 0.9443271	total: 1.8s	remaining: 449ms
# 8:	learn: 0.8569372	total: 2.07s	remaining: 230ms
# 9:	learn: 0.7787515	total: 2.34s	remaining: 0us
# 0:	learn: 1.8903201	total: 256ms	remaining: 2.3s
# 1:	learn: 1.7088090	total: 531ms	remaining: 2.12s
# 2:	learn: 1.5466868	total: 789ms	remaining: 1.84s
# 3:	learn: 1.3996862	total: 1.04s	remaining: 1.56s
# 4:	learn: 1.2683478	total: 1.2s	remaining: 1.2s
# 5:	learn: 1.1477683	total: 1.48s	remaining: 985ms
# 6:	learn: 1.0398814	total: 1.5s	remaining: 643ms
# 7:	learn: 0.9415326	total: 1.78s	remaining: 446ms
# 8:	learn: 0.8527528	total: 2.06s	remaining: 229ms
# 9:	learn: 0.7729767	total: 2.3s	remaining: 0us
# 0:	learn: 1.8878760	total: 284ms	remaining: 2.56s
# 1:	learn: 1.7073183	total: 573ms	remaining: 2.29s
# 2:	learn: 1.5453990	total: 838ms	remaining: 1.96s
# 3:	learn: 1.3981714	total: 1.11s	remaining: 1.66s
# 4:	learn: 1.2658032	total: 1.37s	remaining: 1.37s
# 5:	learn: 1.1462705	total: 1.65s	remaining: 1.1s
# 6:	learn: 1.0389860	total: 1.92s	remaining: 822ms
# 7:	learn: 0.9406259	total: 2.19s	remaining: 548ms
# 8:	learn: 0.8527448	total: 2.44s	remaining: 272ms
# 9:	learn: 0.7735225	total: 2.69s	remaining: 0us
# 0:	learn: 1.8818396	total: 276ms	remaining: 2.48s
# 1:	learn: 1.7009671	total: 532ms	remaining: 2.13s
# 2:	learn: 1.5383396	total: 812ms	remaining: 1.9s
# 3:	learn: 1.3919057	total: 1.08s	remaining: 1.62s
# 4:	learn: 1.2598150	total: 1.38s	remaining: 1.38s
# 5:	learn: 1.1397848	total: 1.65s	remaining: 1.1s
# 6:	learn: 1.0321079	total: 1.92s	remaining: 824ms
# 7:	learn: 0.9339088	total: 2.2s	remaining: 550ms
# 8:	learn: 0.8460616	total: 2.46s	remaining: 274ms
# 9:	learn: 0.7668601	total: 2.73s	remaining: 0us
# 0:	learn: 1.8925583	total: 263ms	remaining: 2.37s
# 1:	learn: 1.7106318	total: 530ms	remaining: 2.12s
# 2:	learn: 1.5461154	total: 794ms	remaining: 1.85s
# 3:	learn: 1.3985317	total: 1.05s	remaining: 1.58s
# 4:	learn: 1.2641173	total: 1.36s	remaining: 1.36s
# 5:	learn: 1.1443035	total: 1.63s	remaining: 1.08s
# 6:	learn: 1.0381010	total: 1.64s	remaining: 703ms
# 7:	learn: 0.9392531	total: 1.88s	remaining: 469ms
# 8:	learn: 0.8507690	total: 2.14s	remaining: 237ms
# 9:	learn: 0.7709172	total: 2.41s	remaining: 0us
# 0:	learn: 1.8835892	total: 292ms	remaining: 2.63s
# 1:	learn: 1.7024456	total: 569ms	remaining: 2.28s
# 2:	learn: 1.5391240	total: 861ms	remaining: 2.01s
# 3:	learn: 1.3921227	total: 1.14s	remaining: 1.7s
# 4:	learn: 1.2583227	total: 1.42s	remaining: 1.42s
# 5:	learn: 1.1379068	total: 1.67s	remaining: 1.11s
# 6:	learn: 1.0300621	total: 1.92s	remaining: 822ms
# 7:	learn: 0.9326780	total: 2.21s	remaining: 551ms
# 8:	learn: 0.8450294	total: 2.46s	remaining: 273ms
# 9:	learn: 0.7675169	total: 2.48s	remaining: 0us
# 0:	learn: 1.8879928	total: 233ms	remaining: 2.1s
# 1:	learn: 1.7063929	total: 500ms	remaining: 2s
# 2:	learn: 1.5426060	total: 766ms	remaining: 1.79s
# 3:	learn: 1.3953703	total: 1.01s	remaining: 1.52s
# 4:	learn: 1.2615147	total: 1.3s	remaining: 1.3s
# 5:	learn: 1.1407751	total: 1.56s	remaining: 1.04s
# 6:	learn: 1.0345955	total: 1.57s	remaining: 675ms
# 7:	learn: 0.9361116	total: 1.83s	remaining: 458ms
# 8:	learn: 0.8480219	total: 2.09s	remaining: 233ms
# 9:	learn: 0.7687067	total: 2.38s	remaining: 0us
# 0:	learn: 1.8848223	total: 290ms	remaining: 2.61s
# 1:	learn: 1.7030088	total: 546ms	remaining: 2.18s
# 2:	learn: 1.5395416	total: 808ms	remaining: 1.89s
# 3:	learn: 1.3923777	total: 1.07s	remaining: 1.6s
# 4:	learn: 1.2587636	total: 1.33s	remaining: 1.33s
# 5:	learn: 1.1377770	total: 1.62s	remaining: 1.08s
# 6:	learn: 1.0294951	total: 1.88s	remaining: 808ms
# 7:	learn: 0.9319046	total: 2.14s	remaining: 534ms
# 8:	learn: 0.8439711	total: 2.4s	remaining: 266ms
# 9:	learn: 0.7658347	total: 2.42s	remaining: 0us
# 0:	learn: 1.8874625	total: 278ms	remaining: 2.5s
# 1:	learn: 1.7056416	total: 582ms	remaining: 2.33s
# 2:	learn: 1.5410200	total: 832ms	remaining: 1.94s
# 3:	learn: 1.3939955	total: 1.1s	remaining: 1.65s
# 4:	learn: 1.2603989	total: 1.33s	remaining: 1.33s
# 5:	learn: 1.1396394	total: 1.62s	remaining: 1.08s
# 6:	learn: 1.0337069	total: 1.63s	remaining: 701ms
# 7:	learn: 0.9350952	total: 1.92s	remaining: 480ms
# 8:	learn: 0.8467412	total: 2.21s	remaining: 246ms
# 9:	learn: 0.7682048	total: 2.49s	remaining: 0us
# 0:	learn: 1.8851563	total: 270ms	remaining: 2.43s
# 1:	learn: 1.7032754	total: 568ms	remaining: 2.27s
# 2:	learn: 1.5392677	total: 886ms	remaining: 2.07s
# 3:	learn: 1.3923168	total: 1.14s	remaining: 1.72s
# 4:	learn: 1.2590231	total: 1.4s	remaining: 1.4s
# 5:	learn: 1.1382666	total: 1.67s	remaining: 1.11s
# 6:	learn: 1.0299176	total: 1.95s	remaining: 837ms
# 7:	learn: 0.9322539	total: 2.23s	remaining: 557ms
# 8:	learn: 0.8438533	total: 2.51s	remaining: 279ms
# 9:	learn: 0.7652000	total: 2.77s	remaining: 0us
# 0:	learn: 1.8866676	total: 267ms	remaining: 2.41s
# 1:	learn: 1.7049397	total: 525ms	remaining: 2.1s
# 2:	learn: 1.5410238	total: 791ms	remaining: 1.84s
# 3:	learn: 1.3932643	total: 1.04s	remaining: 1.56s
# 4:	learn: 1.2590163	total: 1.31s	remaining: 1.31s
# 5:	learn: 1.1378072	total: 1.58s	remaining: 1.05s
# 6:	learn: 1.0310610	total: 1.83s	remaining: 784ms
# 7:	learn: 0.9332887	total: 2.11s	remaining: 527ms
# 8:	learn: 0.8454215	total: 2.37s	remaining: 263ms
# 9:	learn: 0.7658883	total: 2.64s	remaining: 0us
# 0:	learn: 1.8854481	total: 257ms	remaining: 2.31s
# 1:	learn: 1.7025697	total: 539ms	remaining: 2.15s
# 2:	learn: 1.5373766	total: 811ms	remaining: 1.89s
# 3:	learn: 1.3899107	total: 1.05s	remaining: 1.58s
# 4:	learn: 1.2563637	total: 1.31s	remaining: 1.31s
# 5:	learn: 1.1361528	total: 1.57s	remaining: 1.05s
# 6:	learn: 1.0276762	total: 1.85s	remaining: 792ms
# 7:	learn: 0.9300424	total: 2.13s	remaining: 531ms
# 8:	learn: 0.8420377	total: 2.41s	remaining: 268ms
# 9:	learn: 0.7645172	total: 2.44s	remaining: 0us
# 0:	learn: 1.8863542	total: 291ms	remaining: 2.62s
# 1:	learn: 1.7045959	total: 563ms	remaining: 2.25s
# 2:	learn: 1.5392662	total: 845ms	remaining: 1.97s
# 3:	learn: 1.3908403	total: 1.1s	remaining: 1.66s
# 4:	learn: 1.2571188	total: 1.36s	remaining: 1.36s
# 5:	learn: 1.1364545	total: 1.63s	remaining: 1.08s
# 6:	learn: 1.0301598	total: 1.64s	remaining: 704ms
# 7:	learn: 0.9316378	total: 1.91s	remaining: 477ms
# 8:	learn: 0.8435553	total: 2.17s	remaining: 241ms
# 9:	learn: 0.7645740	total: 2.42s	remaining: 0us
# 0:	learn: 1.8870861	total: 257ms	remaining: 2.31s
# 1:	learn: 1.7053841	total: 501ms	remaining: 2s
# 2:	learn: 1.5417684	total: 784ms	remaining: 1.83s
# 3:	learn: 1.3939402	total: 1.03s	remaining: 1.55s
# 4:	learn: 1.2604365	total: 1.33s	remaining: 1.33s
# 5:	learn: 1.1391176	total: 1.56s	remaining: 1.04s
# 6:	learn: 1.0298206	total: 1.83s	remaining: 785ms
# 7:	learn: 0.9316661	total: 2.09s	remaining: 522ms
# 8:	learn: 0.8431605	total: 2.37s	remaining: 264ms
# 9:	learn: 0.7638780	total: 2.63s	remaining: 0us
# 0:	learn: 1.8845526	total: 291ms	remaining: 2.62s
# 1:	learn: 1.7018814	total: 569ms	remaining: 2.28s
# 2:	learn: 1.5370280	total: 844ms	remaining: 1.97s
# 3:	learn: 1.3891210	total: 1.1s	remaining: 1.65s
# 4:	learn: 1.2549704	total: 1.37s	remaining: 1.37s
# 5:	learn: 1.1353164	total: 1.62s	remaining: 1.08s
# 6:	learn: 1.0281718	total: 1.9s	remaining: 815ms
# 7:	learn: 0.9310067	total: 2.21s	remaining: 552ms
# 8:	learn: 0.8426672	total: 2.49s	remaining: 277ms
# 9:	learn: 0.7636269	total: 2.77s	remaining: 0us
# 0:	learn: 1.8861385	total: 255ms	remaining: 2.3s
# 1:	learn: 1.7044698	total: 504ms	remaining: 2.02s
# 2:	learn: 1.5399112	total: 781ms	remaining: 1.82s
# 3:	learn: 1.3925693	total: 1.07s	remaining: 1.6s
# 4:	learn: 1.2587724	total: 1.31s	remaining: 1.31s
# 5:	learn: 1.1377903	total: 1.59s	remaining: 1.06s
# 6:	learn: 1.0294944	total: 1.85s	remaining: 794ms
# 7:	learn: 0.9311862	total: 2.09s	remaining: 523ms
# 8:	learn: 0.8425223	total: 2.33s	remaining: 259ms
# 9:	learn: 0.7630904	total: 2.59s	remaining: 0us
# 0:	learn: 1.8842569	total: 256ms	remaining: 2.31s
# 1:	learn: 1.7017768	total: 514ms	remaining: 2.06s
# 2:	learn: 1.5369523	total: 776ms	remaining: 1.81s
# 3:	learn: 1.3886982	total: 1.04s	remaining: 1.56s
# 4:	learn: 1.2547288	total: 1.32s	remaining: 1.32s
# 5:	learn: 1.1356014	total: 1.56s	remaining: 1.04s
# 6:	learn: 1.0274090	total: 1.82s	remaining: 782ms
# 7:	learn: 0.9298065	total: 2.1s	remaining: 525ms
# 8:	learn: 0.8413888	total: 2.35s	remaining: 261ms
# 9:	learn: 0.7626939	total: 2.61s	remaining: 0us
# 0:	learn: 1.8857150	total: 269ms	remaining: 2.42s
# 1:	learn: 1.7041459	total: 522ms	remaining: 2.09s
# 2:	learn: 1.5395777	total: 794ms	remaining: 1.85s
# 3:	learn: 1.3922863	total: 1.04s	remaining: 1.56s
# 4:	learn: 1.2584762	total: 1.31s	remaining: 1.31s
# 5:	learn: 1.1377963	total: 1.59s	remaining: 1.06s
# 6:	learn: 1.0296666	total: 1.85s	remaining: 792ms
# 7:	learn: 0.9313266	total: 2.11s	remaining: 528ms
# 8:	learn: 0.8424949	total: 2.39s	remaining: 265ms
# 9:	learn: 0.7628600	total: 2.67s	remaining: 0us
# 0:	learn: 1.8848916	total: 327ms	remaining: 2.95s
# 1:	learn: 1.7027910	total: 605ms	remaining: 2.42s
# 2:	learn: 1.5376061	total: 863ms	remaining: 2.01s
# 3:	learn: 1.3897221	total: 1.11s	remaining: 1.67s
# 4:	learn: 1.2556774	total: 1.36s	remaining: 1.36s
# 5:	learn: 1.1360942	total: 1.65s	remaining: 1.1s
# 6:	learn: 1.0279558	total: 1.93s	remaining: 826ms
# 7:	learn: 0.9303008	total: 2.19s	remaining: 547ms
# 8:	learn: 0.8418407	total: 2.45s	remaining: 272ms
# 9:	learn: 0.7641794	total: 2.47s	remaining: 0us
# 0:	learn: 1.1062256	total: 277ms	remaining: 2.49s
# 1:	learn: 0.6135677	total: 519ms	remaining: 2.08s
# 2:	learn: 0.3654264	total: 750ms	remaining: 1.75s
# 3:	learn: 0.2489386	total: 1.01s	remaining: 1.52s
# 4:	learn: 0.2004218	total: 1.28s	remaining: 1.28s
# 5:	learn: 0.1783354	total: 1.53s	remaining: 1.02s
# 6:	learn: 0.1669990	total: 1.8s	remaining: 770ms
# 7:	learn: 0.1609877	total: 2.07s	remaining: 519ms
# 8:	learn: 0.1560162	total: 2.35s	remaining: 261ms
# 9:	learn: 0.1520801	total: 2.59s	remaining: 0us
# 0:	learn: 1.1025787	total: 248ms	remaining: 2.23s
# 1:	learn: 0.6079175	total: 500ms	remaining: 2s
# 2:	learn: 0.3577085	total: 758ms	remaining: 1.77s
# 3:	learn: 0.2458702	total: 1.02s	remaining: 1.53s
# 4:	learn: 0.1995504	total: 1.07s	remaining: 1.07s
# 5:	learn: 0.1807790	total: 1.32s	remaining: 880ms
# 6:	learn: 0.1710608	total: 1.58s	remaining: 676ms
# 7:	learn: 0.1650381	total: 1.83s	remaining: 459ms
# 8:	learn: 0.1604328	total: 2.1s	remaining: 233ms
# 9:	learn: 0.1574624	total: 2.39s	remaining: 0us
# 0:	learn: 1.0929447	total: 238ms	remaining: 2.15s
# 1:	learn: 0.5932492	total: 491ms	remaining: 1.96s
# 2:	learn: 0.3459795	total: 744ms	remaining: 1.74s
# 3:	learn: 0.2366253	total: 1.02s	remaining: 1.54s
# 4:	learn: 0.1953493	total: 1.17s	remaining: 1.17s
# 5:	learn: 0.1757704	total: 1.44s	remaining: 963ms
# 6:	learn: 0.1654495	total: 1.71s	remaining: 732ms
# 7:	learn: 0.1576838	total: 1.98s	remaining: 495ms
# 8:	learn: 0.1527325	total: 2.23s	remaining: 248ms
# 9:	learn: 0.1489570	total: 2.49s	remaining: 0us
# 0:	learn: 1.0966794	total: 261ms	remaining: 2.35s
# 1:	learn: 0.6012552	total: 510ms	remaining: 2.04s
# 2:	learn: 0.3516485	total: 754ms	remaining: 1.76s
# 3:	learn: 0.2456427	total: 1.04s	remaining: 1.56s
# 4:	learn: 0.1973822	total: 1.31s	remaining: 1.31s
# 5:	learn: 0.1763058	total: 1.56s	remaining: 1.04s
# 6:	learn: 0.1659860	total: 1.82s	remaining: 780ms
# 7:	learn: 0.1585702	total: 2.1s	remaining: 524ms
# 8:	learn: 0.1536367	total: 2.36s	remaining: 262ms
# 9:	learn: 0.1496877	total: 2.63s	remaining: 0us
# 0:	learn: 1.0865983	total: 249ms	remaining: 2.24s
# 1:	learn: 0.5882519	total: 511ms	remaining: 2.04s
# 2:	learn: 0.3420764	total: 783ms	remaining: 1.83s
# 3:	learn: 0.2328289	total: 1.06s	remaining: 1.58s
# 4:	learn: 0.1906051	total: 1.19s	remaining: 1.19s
# 5:	learn: 0.1720719	total: 1.44s	remaining: 960ms
# 6:	learn: 0.1619881	total: 1.68s	remaining: 719ms
# 7:	learn: 0.1544701	total: 1.96s	remaining: 491ms
# 8:	learn: 0.1503275	total: 2.26s	remaining: 251ms
# 9:	learn: 0.1471253	total: 2.48s	remaining: 0us
# 0:	learn: 1.0987050	total: 269ms	remaining: 2.42s
# 1:	learn: 0.5951110	total: 523ms	remaining: 2.09s
# 2:	learn: 0.3498981	total: 772ms	remaining: 1.8s
# 3:	learn: 0.2412748	total: 1.02s	remaining: 1.53s
# 4:	learn: 0.1986056	total: 1.29s	remaining: 1.29s
# 5:	learn: 0.1762944	total: 1.53s	remaining: 1.02s
# 6:	learn: 0.1649888	total: 1.8s	remaining: 773ms
# 7:	learn: 0.1602974	total: 2.11s	remaining: 527ms
# 8:	learn: 0.1536389	total: 2.36s	remaining: 262ms
# 9:	learn: 0.1505386	total: 2.61s	remaining: 0us
# 0:	learn: 1.0874049	total: 265ms	remaining: 2.38s
# 1:	learn: 0.5849338	total: 511ms	remaining: 2.04s
# 2:	learn: 0.3404562	total: 754ms	remaining: 1.76s
# 3:	learn: 0.2336591	total: 1.01s	remaining: 1.52s
# 4:	learn: 0.1922020	total: 1.14s	remaining: 1.14s
# 5:	learn: 0.1719522	total: 1.41s	remaining: 942ms
# 6:	learn: 0.1623783	total: 1.67s	remaining: 716ms
# 7:	learn: 0.1545225	total: 1.92s	remaining: 481ms
# 8:	learn: 0.1510038	total: 2.18s	remaining: 242ms
# 9:	learn: 0.1469324	total: 2.45s	remaining: 0us
# 0:	learn: 1.0945270	total: 265ms	remaining: 2.38s
# 1:	learn: 0.5867606	total: 530ms	remaining: 2.12s
# 2:	learn: 0.3411605	total: 801ms	remaining: 1.87s
# 3:	learn: 0.2353102	total: 1.05s	remaining: 1.58s
# 4:	learn: 0.1928962	total: 1.34s	remaining: 1.34s
# 5:	learn: 0.1723657	total: 1.59s	remaining: 1.06s
# 6:	learn: 0.1639724	total: 1.84s	remaining: 788ms
# 7:	learn: 0.1562182	total: 2.07s	remaining: 518ms
# 8:	learn: 0.1526613	total: 2.34s	remaining: 260ms
# 9:	learn: 0.1492404	total: 2.58s	remaining: 0us
# 0:	learn: 1.0882590	total: 288ms	remaining: 2.59s
# 1:	learn: 0.5802684	total: 515ms	remaining: 2.06s
# 2:	learn: 0.3399829	total: 526ms	remaining: 1.23s
# 3:	learn: 0.2290119	total: 775ms	remaining: 1.16s
# 4:	learn: 0.1835890	total: 1.03s	remaining: 1.03s
# 5:	learn: 0.1677534	total: 1.27s	remaining: 847ms
# 6:	learn: 0.1579837	total: 1.51s	remaining: 646ms
# 7:	learn: 0.1514598	total: 1.77s	remaining: 443ms
# 8:	learn: 0.1479092	total: 2.03s	remaining: 226ms
# 9:	learn: 0.1457396	total: 2.28s	remaining: 0us
# 0:	learn: 1.0893537	total: 273ms	remaining: 2.46s
# 1:	learn: 0.5832866	total: 546ms	remaining: 2.18s
# 2:	learn: 0.3388998	total: 802ms	remaining: 1.87s
# 3:	learn: 0.2301678	total: 1.04s	remaining: 1.56s
# 4:	learn: 0.1865630	total: 1.3s	remaining: 1.3s
# 5:	learn: 0.1705965	total: 1.56s	remaining: 1.04s
# 6:	learn: 0.1616219	total: 1.81s	remaining: 775ms
# 7:	learn: 0.1544080	total: 2.05s	remaining: 513ms
# 8:	learn: 0.1508256	total: 2.33s	remaining: 259ms
# 9:	learn: 0.1466474	total: 2.58s	remaining: 0us
# 0:	learn: 1.0845323	total: 243ms	remaining: 2.19s
# 1:	learn: 0.5791096	total: 525ms	remaining: 2.1s
# 2:	learn: 0.3339929	total: 817ms	remaining: 1.91s
# 3:	learn: 0.2278795	total: 1.09s	remaining: 1.64s
# 4:	learn: 0.1846329	total: 1.36s	remaining: 1.36s
# 5:	learn: 0.1663211	total: 1.62s	remaining: 1.08s
# 6:	learn: 0.1575241	total: 1.89s	remaining: 812ms
# 7:	learn: 0.1504796	total: 2.16s	remaining: 540ms
# 8:	learn: 0.1471682	total: 2.42s	remaining: 269ms
# 9:	learn: 0.1430433	total: 2.68s	remaining: 0us
# 0:	learn: 1.0883984	total: 264ms	remaining: 2.38s
# 1:	learn: 0.5860781	total: 518ms	remaining: 2.07s
# 2:	learn: 0.3405863	total: 788ms	remaining: 1.84s
# 3:	learn: 0.2335008	total: 1.05s	remaining: 1.58s
# 4:	learn: 0.1904683	total: 1.31s	remaining: 1.31s
# 5:	learn: 0.1723037	total: 1.6s	remaining: 1.07s
# 6:	learn: 0.1605751	total: 1.83s	remaining: 784ms
# 7:	learn: 0.1538768	total: 2.11s	remaining: 527ms
# 8:	learn: 0.1491321	total: 2.39s	remaining: 265ms
# 9:	learn: 0.1452864	total: 2.61s	remaining: 0us
# 0:	learn: 1.0865126	total: 267ms	remaining: 2.4s
# 1:	learn: 0.5820474	total: 547ms	remaining: 2.19s
# 2:	learn: 0.3362023	total: 822ms	remaining: 1.92s
# 3:	learn: 0.2294153	total: 1.07s	remaining: 1.6s
# 4:	learn: 0.1885557	total: 1.32s	remaining: 1.32s
# 5:	learn: 0.1686767	total: 1.58s	remaining: 1.06s
# 6:	learn: 0.1599831	total: 1.86s	remaining: 797ms
# 7:	learn: 0.1541501	total: 2.11s	remaining: 528ms
# 8:	learn: 0.1492154	total: 2.35s	remaining: 262ms
# 9:	learn: 0.1451549	total: 2.63s	remaining: 0us
# 0:	learn: 1.0923786	total: 276ms	remaining: 2.48s
# 1:	learn: 0.5851161	total: 549ms	remaining: 2.2s
# 2:	learn: 0.3384783	total: 799ms	remaining: 1.86s
# 3:	learn: 0.2321859	total: 1.08s	remaining: 1.62s
# 4:	learn: 0.1904321	total: 1.23s	remaining: 1.23s
# 5:	learn: 0.1678755	total: 1.51s	remaining: 1.01s
# 6:	learn: 0.1600387	total: 1.79s	remaining: 766ms
# 7:	learn: 0.1519377	total: 2.02s	remaining: 506ms
# 8:	learn: 0.1481947	total: 2.3s	remaining: 255ms
# 9:	learn: 0.1450559	total: 2.54s	remaining: 0us
# 0:	learn: 1.0930748	total: 289ms	remaining: 2.6s
# 1:	learn: 0.5849373	total: 535ms	remaining: 2.14s
# 2:	learn: 0.3391566	total: 800ms	remaining: 1.87s
# 3:	learn: 0.2307867	total: 1.05s	remaining: 1.58s
# 4:	learn: 0.1883478	total: 1.33s	remaining: 1.33s
# 5:	learn: 0.1702094	total: 1.6s	remaining: 1.07s
# 6:	learn: 0.1589650	total: 1.88s	remaining: 807ms
# 7:	learn: 0.1533596	total: 2.16s	remaining: 540ms
# 8:	learn: 0.1493568	total: 2.46s	remaining: 273ms
# 9:	learn: 0.1457637	total: 2.71s	remaining: 0us
# 0:	learn: 1.0899534	total: 262ms	remaining: 2.35s
# 1:	learn: 0.5858255	total: 493ms	remaining: 1.97s
# 2:	learn: 0.3422114	total: 738ms	remaining: 1.72s
# 3:	learn: 0.2318719	total: 994ms	remaining: 1.49s
# 4:	learn: 0.1871154	total: 1.26s	remaining: 1.26s
# 5:	learn: 0.1691686	total: 1.53s	remaining: 1.02s
# 6:	learn: 0.1582404	total: 1.81s	remaining: 775ms
# 7:	learn: 0.1539572	total: 2.06s	remaining: 514ms
# 8:	learn: 0.1496667	total: 2.32s	remaining: 258ms
# 9:	learn: 0.1466707	total: 2.6s	remaining: 0us
# 0:	learn: 1.0924086	total: 271ms	remaining: 2.44s
# 1:	learn: 0.5843571	total: 555ms	remaining: 2.22s
# 2:	learn: 0.3371765	total: 842ms	remaining: 1.96s
# 3:	learn: 0.2272827	total: 1.1s	remaining: 1.65s
# 4:	learn: 0.1824807	total: 1.37s	remaining: 1.37s
# 5:	learn: 0.1648356	total: 1.62s	remaining: 1.08s
# 6:	learn: 0.1547696	total: 1.87s	remaining: 803ms
# 7:	learn: 0.1490900	total: 2.17s	remaining: 543ms
# 8:	learn: 0.1452828	total: 2.42s	remaining: 268ms
# 9:	learn: 0.1431489	total: 2.68s	remaining: 0us
# 0:	learn: 1.0872577	total: 253ms	remaining: 2.28s
# 1:	learn: 0.5862745	total: 489ms	remaining: 1.96s
# 2:	learn: 0.3377893	total: 735ms	remaining: 1.71s
# 3:	learn: 0.2268259	total: 998ms	remaining: 1.5s
# 4:	learn: 0.1821925	total: 1.27s	remaining: 1.27s
# 5:	learn: 0.1644587	total: 1.54s	remaining: 1.03s
# 6:	learn: 0.1559194	total: 1.8s	remaining: 772ms
# 7:	learn: 0.1511343	total: 2.08s	remaining: 520ms
# 8:	learn: 0.1468305	total: 2.34s	remaining: 260ms
# 9:	learn: 0.1436125	total: 2.62s	remaining: 0us
# 0:	learn: 1.0920094	total: 307ms	remaining: 2.76s
# 1:	learn: 0.5813719	total: 560ms	remaining: 2.24s
# 2:	learn: 0.3360744	total: 847ms	remaining: 1.98s
# 3:	learn: 0.2282433	total: 1.12s	remaining: 1.68s
# 4:	learn: 0.1868600	total: 1.39s	remaining: 1.39s
# 5:	learn: 0.1685861	total: 1.64s	remaining: 1.09s
# 6:	learn: 0.1573848	total: 1.9s	remaining: 813ms
# 7:	learn: 0.1518293	total: 2.17s	remaining: 542ms
# 8:	learn: 0.1474894	total: 2.46s	remaining: 274ms
# 9:	learn: 0.1439258	total: 2.71s	remaining: 0us
# 0:	learn: 1.0872402	total: 282ms	remaining: 2.54s
# 1:	learn: 0.5815949	total: 549ms	remaining: 2.19s
# 2:	learn: 0.3360159	total: 850ms	remaining: 1.98s
# 3:	learn: 0.2278164	total: 1.11s	remaining: 1.67s
# 4:	learn: 0.1827976	total: 1.36s	remaining: 1.36s
# 5:	learn: 0.1661803	total: 1.62s	remaining: 1.08s
# 6:	learn: 0.1580370	total: 1.88s	remaining: 807ms
# 7:	learn: 0.1523619	total: 2.13s	remaining: 533ms
# 8:	learn: 0.1492475	total: 2.39s	remaining: 266ms
# 9:	learn: 0.1453398	total: 2.68s	remaining: 0us
# 0:	learn: 1.0893911	total: 273ms	remaining: 2.46s
# 1:	learn: 0.5836045	total: 538ms	remaining: 2.15s
# 2:	learn: 0.3420483	total: 807ms	remaining: 1.88s
# 3:	learn: 0.2300432	total: 1.06s	remaining: 1.59s
# 4:	learn: 0.1860792	total: 1.35s	remaining: 1.35s
# 5:	learn: 0.1676949	total: 1.6s	remaining: 1.07s
# 6:	learn: 0.1589583	total: 1.88s	remaining: 807ms
# 7:	learn: 0.1537275	total: 2.16s	remaining: 539ms
# 8:	learn: 0.1474768	total: 2.46s	remaining: 274ms
# 9:	learn: 0.1445163	total: 2.75s	remaining: 0us
# 0:	learn: 1.0838398	total: 273ms	remaining: 2.45s
# 1:	learn: 0.5854285	total: 512ms	remaining: 2.05s
# 2:	learn: 0.3384481	total: 771ms	remaining: 1.8s
# 3:	learn: 0.2258924	total: 1.05s	remaining: 1.58s
# 4:	learn: 0.1812002	total: 1.31s	remaining: 1.31s
# 5:	learn: 0.1636641	total: 1.6s	remaining: 1.07s
# 6:	learn: 0.1553725	total: 1.85s	remaining: 791ms
# 7:	learn: 0.1507347	total: 2.12s	remaining: 531ms
# 8:	learn: 0.1466213	total: 2.38s	remaining: 265ms
# 9:	learn: 0.1439352	total: 2.64s	remaining: 0us
# RMSE TRAIN: 0.3844900461960947
# TIME TRAIN [s]: 5.53

# %% [markdown]
# **Проверка на валидационной выборки**

# %%
# %%time
start_time = timeit.default_timer()
# Получим предсказания на валидационной выборки
predictions = model.predict(features_valid)

elapsed = round(timeit.default_timer() - start_time, 3)

# Узнаем RMSE output_real и output_imag
rmse_valid_real = np.sqrt(mean_squared_error(targets_valid['output_real'], predictions[:, 0]))
rmse_valid_imag = np.sqrt(mean_squared_error(targets_valid['output_imag'], predictions[:, 1]))

print(f'RMSE для действительной части: {rmse_valid_real}')
print(f'RMSE для мнимой части: {rmse_valid_imag}')
# Out:
# RMSE для действительной части: 0.14433298570142392
# RMSE для мнимой части: 0.1442852424131891
# CPU times: user 18.5 ms, sys: 5.55 ms, total: 24 ms
# Wall time: 6.42 ms

# %%
# Зафиксируем результаты
results[count_model] = pd.Series({
    'NAME': pipeline_scale.named_steps[pipeline_scale.steps[-1][0]].__class__.__name__, 
    'RMSE TRAIN': rmse_train, 
    'RMSE VALID REAL': rmse_valid_real, 
    'RMSE VALID IMAG': rmse_valid_imag, 
    'TIME TRAINING [s]': model.refit_time_, 
    'TIME PREDICTION [s]': elapsed, 
    'PREDICTIONS': predictions, 
    'PARAMETRS': model.best_params_
})

display(results[count_model])
count_model+=1
# Out:
# NAME                                                MultiOutputRegressor
# RMSE TRAIN                                                       0.38449
# RMSE VALID REAL                                                 0.144333
# RMSE VALID IMAG                                                 0.144285
# TIME TRAINING [s]                                               5.530213
# TIME PREDICTION [s]                                                0.006
# PREDICTIONS            [[-0.5793409857007769, 3.00895793161571], [-2....
# PARAMETRS              {'multioutputregressor__estimator__depth': 15,...
# Name: 4, dtype: object

# %% [markdown]
# ### BaggingRegressor

# %%
# Матрица гиперпараметров для BaggingRegressor
parameters = {
    'baggingregressor__n_estimators': [10, 25],
    'baggingregressor__random_state': [12345] 
}

# Инициализируем модель с параметрами и создаем конвейер
# Инициализируем BaggingRegressor отдельно
bagging_model = BaggingRegressor(estimator=DecisionTreeRegressor(max_depth=10), random_state=12345)
pipeline_scale = make_pipeline(StandardScaler(), bagging_model)
model = GridSearchCV(pipeline_scale, param_grid=parameters, cv=tscv, scoring='neg_root_mean_squared_error')
display(model)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=10, test_size=None),
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('baggingregressor',
#                                         BaggingRegressor(estimator=DecisionTreeRegressor(max_depth=10),
#                                                          random_state=12345))]),
#              param_grid={'baggingregressor__n_estimators': [10, 25],
#                          'baggingregressor__random_state': [12345]},
#              scoring='neg_root_mean_squared_error')

# %%
# Обучим модель на обучающей выборке
model.fit(features_train, targets_train)
time = model.refit_time_
params = model.best_params_

# Узнаем RMSE обучающей выборки
rmse_train = np.sqrt(-model.best_score_)
print('RMSE TRAIN:', rmse_train)
print('TIME TRAIN [s]:', round(time, 2))
# Out:
# RMSE TRAIN: 0.35696216171103107
# TIME TRAIN [s]: 4.5

# %% [markdown]
# **Проверка на валидационной выборки**

# %%
# %%time
start_time = timeit.default_timer()
# Получим предсказания на валидационной выборки
predictions = model.predict(features_valid)

elapsed = round(timeit.default_timer() - start_time, 3)

# Узнаем RMSE output_real и output_imag
rmse_valid_real = np.sqrt(mean_squared_error(targets_valid['output_real'], predictions[:, 0]))
rmse_valid_imag = np.sqrt(mean_squared_error(targets_valid['output_imag'], predictions[:, 1]))

print(f'RMSE для действительной части: {rmse_valid_real}')
print(f'RMSE для мнимой части: {rmse_valid_imag}')
# Out:
# RMSE для действительной части: 0.12555557093909708
# RMSE для мнимой части: 0.1261163382483048
# CPU times: user 74.8 ms, sys: 953 µs, total: 75.8 ms
# Wall time: 74.7 ms

# %%
# Зафиксируем результаты
results[count_model] = pd.Series({
    'NAME': pipeline_scale.named_steps[pipeline_scale.steps[-1][0]].__class__.__name__, 
    'RMSE TRAIN': rmse_train, 
    'RMSE VALID REAL': rmse_valid_real, 
    'RMSE VALID IMAG': rmse_valid_imag, 
    'TIME TRAINING [s]': model.refit_time_, 
    'TIME PREDICTION [s]': elapsed, 
    'PREDICTIONS': predictions, 
    'PARAMETRS': model.best_params_
})

display(results[count_model])
count_model+=1
# Out:
# NAME                                                    BaggingRegressor
# RMSE TRAIN                                                      0.356962
# RMSE VALID REAL                                                 0.125556
# RMSE VALID IMAG                                                 0.126116
# TIME TRAINING [s]                                               4.503093
# TIME PREDICTION [s]                                                0.073
# PREDICTIONS            [[-0.5211061075152857, 3.000718101419898], [-2...
# PARAMETRS              {'baggingregressor__n_estimators': 25, 'baggin...
# Name: 5, dtype: object

# %% [markdown]
# ## Результаты

# %%
results = pd.DataFrame(results).T

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NAME                 1 non-null      object
#  1   RMSE TRAIN           1 non-null      object
#  2   RMSE VALID REAL      1 non-null      object
#  3   RMSE VALID IMAG      1 non-null      object
#  4   TIME TRAINING [s]    1 non-null      object
#  5   TIME PREDICTION [s]  1 non-null      object
#  6   PREDICTIONS          1 non-null      object
#  7   PARAMETRS            1 non-null      object
# dtypes: object(8)
# memory usage: 180.0+ bytes

# %%
predictions = results.PREDICTIONS.iloc[0]  # Получаем список предсказаний
length = len(predictions)  # Вычисляем длину списка
print(f"Длина предсказания: {length}")
# Out:
# Длина предсказания: 34407

# %%
results.PREDICTIONS
# Out:
# 0    [[-0.28832698573917814, 1.936889405288186], [-...
# Name: PREDICTIONS, dtype: object

# %%
# Смотрим на результаты
display(results)
# Out:
#                NAME RMSE TRAIN RMSE VALID REAL RMSE VALID IMAG  \
# 0  LinearRegression   0.865867         0.74888        0.753163
#
#   TIME TRAINING [s] TIME PREDICTION [s]  \
# 0          0.018766               0.004
#
#                                          PREDICTIONS PARAMETRS
# 0  [[-0.28832698573917814, 1.936889405288186], [-...        {}

# %%
# Рассчитываем рейтинг с учетом указанных приоритетов
results['RATING'] = (
    0.45 * (1 - (results['RMSE VALID REAL'] / results['RMSE VALID REAL'].max())) +
    0.45 * (1 - (results['RMSE VALID IMAG'] / results['RMSE VALID IMAG'].max())) +
    0.1 * (1 - (results['TIME TRAINING [s]'] / results['TIME TRAINING [s]'].max()))
    # 0.1 * (1 - (results['TIME PREDICTION [s]'] / results['TIME PREDICTION [s]'].max()))
)

# Сортируем DataFrame по убыванию рейтинга
results = results.sort_values(by='RATING', ascending=False)

# %%
# Смотрим на результаты
display(results)
# Out:
#                     NAME RMSE TRAIN RMSE VALID REAL RMSE VALID IMAG  \
# 2  DecisionTreeRegressor   0.376215        0.134598        0.133988
# 1    KNeighborsRegressor   0.386294        0.147566        0.148368
# 3   MultiOutputRegressor   0.416362         0.17133        0.172387
# 5       BaggingRegressor   0.356962        0.125556        0.126116
# 4   MultiOutputRegressor    0.38449        0.144333        0.144285
# 0       LinearRegression   0.865867         0.74888        0.753163
#
#   TIME TRAINING [s] TIME PREDICTION [s]  \
# 2          0.296888               0.005
# 1          0.061688               0.102
# 3          0.126176               0.016
# 5          4.503093               0.073
# 4          5.530213               0.006
# 0          0.020961               0.003
#
#                                          PREDICTIONS  \
# 2  [[-0.5637410662983423, 2.8974165193370167], [-...
# 1  [[-0.44020349999999997, 2.974165], [-2.74305, ...
# 3  [[-0.33606733176649484, 3.0045329003957586], [...
# 5  [[-0.5211061075152857, 3.000718101419898], [-2...
# 4  [[-0.5793409857007769, 3.00895793161571], [-2....
# 0  [[-0.28832698573917814, 1.936889405288186], [-...
#
#                                            PARAMETRS    RATING
# 2  {'decisiontreeregressor__max_depth': 11, 'deci...  0.833697
# 1  {'kneighborsregressor__n_neighbors': 2, 'kneig...  0.821566
# 3  {'multioutputregressor__estimator__learning_ra...  0.791769
# 5  {'baggingregressor__n_estimators': 25, 'baggin...  0.767775
# 4  {'multioutputregressor__estimator__depth': 15,...  0.727063
# 0                                                 {}  0.099621

# %% [markdown]
# **Создадим отдельный датасет, в котором будет храниться реальное значение и предсказания модели**

# %%
# Используем индексы валидационных данных
info_result = pd.DataFrame(index=targets_valid.index)

info_result['default_real'] = targets_valid['output_real']
info_result['default_imag'] = targets_valid['output_imag']

for i, name_model in enumerate(results['NAME']):
    info_result[name_model+'_real'] = results['PREDICTIONS'][i][:, 0]  # Предсказанные значения действительной части
    info_result[name_model+'_imag'] = results['PREDICTIONS'][i][:, 1]  # Предсказанные значения действительной части

# Сортировка DataFrame по индексу
info_result = info_result.sort_index()

info_result.head()
# Out:
#               default_real  default_imag  DecisionTreeRegressor_real  \
# time
# 6.500000e-08      0.000358     -0.001267                   -0.003513
# 8.000000e-08      0.000814     -0.000496                   -0.003214
# 9.000000e-08      0.001889     -0.004296                   -0.003431
# 1.800000e-07     -0.012080     -0.011916                   -0.009650
# 1.900000e-07      0.026646     -0.014216                    0.004099
#
#               DecisionTreeRegressor_imag  KNeighborsRegressor_real  \
# time
# 6.500000e-08                   -0.000698                  0.000346
# 8.000000e-08                   -0.000472                  0.000398
# 9.000000e-08                   -0.002047                  0.001465
# 1.800000e-07                   -0.002516                 -0.015121
# 1.900000e-07                   -0.009515                  0.063197
#
#               KNeighborsRegressor_imag  MultiOutputRegressor_real  \
# time
# 6.500000e-08                 -0.001271                  -0.118049
# 8.000000e-08                 -0.000223                  -0.118049
# 9.000000e-08                 -0.005154                  -0.118049
# 1.800000e-07                 -0.011610                  -0.118049
# 1.900000e-07                 -0.011673                  -0.118049
#
#               MultiOutputRegressor_imag  BaggingRegressor_real  \
# time
# 6.500000e-08                   0.028836               0.552150
# 8.000000e-08                   0.028836               0.552150
# 9.000000e-08                   0.028836               0.552150
# 1.800000e-07                   0.028836              -0.343024
# 1.900000e-07                   0.028836               0.552150
#
#               BaggingRegressor_imag  LinearRegression_real  \
# time
# 6.500000e-08               0.427222              -0.017098
# 8.000000e-08               0.427222              -0.017098
# 9.000000e-08              -0.268951              -0.033412
# 1.800000e-07               0.427222              -0.043926
# 1.900000e-07              -0.268951              -0.012356
#
#               LinearRegression_imag
# time
# 6.500000e-08              -0.007220
# 8.000000e-08              -0.007220
# 9.000000e-08              -0.024787
# 1.800000e-07              -0.027412
# 1.900000e-07              -0.010523

# %%
def plot_predictions_vs_real(info_result, time_start, time_end):
    # Определяем количество моделей, минус 1 для 'default_real' и 'default_imag'
    num_models = len(info_result.columns) // 2 - 1  

    for i in range(num_models):
        col_real = 'default_real'
        col_pred_real = info_result.columns[2 * i + 2]
        col_pred_imag = info_result.columns[2 * i + 3]

        # Фильтрация данных по временной отметке
        filtered_data = info_result[(info_result.index >= time_start) & (info_result.index <= time_end)]
        time = filtered_data.index

        # Создание фигуры с двумя подграфиками
        fig, axs = plt.subplots(1, 2, figsize=(20, 5), sharex=True, sharey=True)
        
        # Общий заголовок для всей фигуры
        fig.suptitle(f'Graph of default and predicted values ({col_pred_real.split("_")[0]})', fontsize=22)

        # Построение графиков реальных значений
        axs[0].plot(time, filtered_data[col_real], alpha=0.7, color='red', lw=2.5, label='default')
        axs[0].plot(time, filtered_data[col_pred_real], alpha=0.7, color='blue', lw=2.5, label='prediction')
        axs[0].legend(fontsize='xx-large')
        axs[0].grid()
        axs[0].set_xlabel('Time series', fontsize=20)
        axs[0].set_ylabel('Value', fontsize=20)
        axs[0].set_title('REAL', fontsize=20)

        # Построение графиков мнимых значений
        axs[1].plot(time, filtered_data['default_imag'], alpha=0.7, color='red', lw=2.5, label='default')
        axs[1].plot(time, filtered_data[col_pred_imag], alpha=0.7, color='blue', lw=2.5, label='prediction')
        axs[1].legend(fontsize='xx-large')
        axs[1].grid()
        axs[1].set_xlabel('Time series', fontsize=20)
        axs[1].set_ylabel('Value', fontsize=20)
        axs[1].set_title('IMAG', fontsize=20)

        # Показываем график
        plt.tight_layout()
        plt.show()

# %%
plot_predictions_vs_real(info_result, time_start=0, time_end=1e-6)

# %%
plot_predictions_vs_real(info_result, time_start=0.5e-5, time_end=1e-5)
